# %%
from google.colab import drive
import pandas as pd
import pickle

# Mount Google Drive
drive.mount('/content/drive')

# Path to data folder
data_path = "/content/drive/MyDrive/3DCV/HW2/Q2/data/"

# List of pickle files
files = ["images.pkl", "point_desc.pkl", "points3D.pkl", "train.pkl"]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **P3p + RANSAC from scratch**

# %% [markdown]
# Image #164 (valid_img10.jpg) — matches: 3580
#
# Rotation (Rodrigues): [0.0552  ...  0.995   ...  0.1425]
#
# Translation: [-3.4498  ...  -0.8014  ...   4.45  ]

# %%
import numpy as np
import pickle
import cv2
from scipy.spatial.transform import Rotation as R

# --- Load data ---
# data_path = "/content/drive/MyDrive/3DCV/HW2/Q2/data/"
# with open(data_path + "images.pkl", "rb") as f:
#     images_df = pickle.load(f)
# with open(data_path + "point_desc.pkl", "rb") as f:
#     point_desc_df = pickle.load(f)
# with open(data_path + "points3D.pkl", "rb") as f:
#     points3D_df = pickle.load(f)

# --- Camera intrinsics and distortion ---
K = np.array([[1868.27, 0, 540],
              [0, 1869.18, 960],
              [0, 0, 1]], dtype=np.float64)
distCoeffs = np.array([[0.0847023, -0.192929, -0.000201144, -0.000725352]], dtype=np.float64)

# --- Build lookup for 3D points ---
point3D_map = {pid: xyz for pid, xyz in zip(points3D_df["POINT_ID"], points3D_df["XYZ"])}

# --- P3P solver (simplified using SVD) ---
def p3p_solver(pts_3D, bearings):
    centroid_3D = np.mean(pts_3D, axis=0)
    P_centered = pts_3D - centroid_3D

    centroid_bear = np.mean(bearings, axis=0)
    U_centered = bearings - centroid_bear

    H = U_centered.T @ P_centered
    U_svd, S, Vt = np.linalg.svd(H)
    R_est = Vt.T @ U_svd.T
    if np.linalg.det(R_est) < 0:
        Vt[-1, :] *= -1
        R_est = Vt.T @ U_svd.T

    t_est = centroid_3D - R_est @ centroid_bear
    return R_est, t_est

# --- Get validation images ---
val_images = images_df[images_df["IMAGE_ID"] > 163]

poses = []

for img_row in val_images.itertuples():
    img_id = img_row.IMAGE_ID
    img_name = img_row.NAME
    print(f"Processing Image ID={img_id}, Name={img_name}")

    # --- Get 2D-3D correspondences ---
    pts_rows = point_desc_df[point_desc_df["IMAGE_ID"] == img_id]
    pts_rows = pts_rows[pts_rows["POINT_ID"] != -1]

    if len(pts_rows) < 6:  # too few points
        continue

    pts_2D = np.stack(pts_rows["XY"].values).astype(np.float64)
    pts_3D = np.array([point3D_map[pid] for pid in pts_rows["POINT_ID"]], dtype=np.float64)

    # --- Undistort points and compute bearings ---
    pts_2D_undist = cv2.undistortPoints(
        pts_2D.reshape(-1, 1, 2), K, distCoeffs
    ).reshape(-1, 2)
    bearings = np.hstack([pts_2D_undist, np.ones((len(pts_2D_undist), 1))])
    bearings /= np.linalg.norm(bearings, axis=1, keepdims=True)

    # --- RANSAC ---
    n_iter = 200
    best_inliers = 0
    best_R = None
    best_t = None
    threshold_angle = 5  # degrees

    for _ in range(n_iter):
        idx = np.random.choice(len(pts_3D), 3, replace=False)
        R_try, t_try = p3p_solver(pts_3D[idx], bearings[idx])

        proj = (R_try @ pts_3D.T + t_try[:, np.newaxis]).T
        proj /= np.linalg.norm(proj, axis=1, keepdims=True)
        cos_sim = np.sum(proj * bearings, axis=1)
        inliers = np.sum(cos_sim > np.cos(np.deg2rad(threshold_angle)))

        if inliers > best_inliers:
            best_inliers = inliers
            best_R = R_try
            best_t = t_try

    if best_R is not None:

        rvec, _ = cv2.Rodrigues(best_R)
        print("R = ", rvec.T,"     t = ", best_t)
        poses.append((img_id, img_name, rvec.ravel(), best_t, best_inliers))

# --- Compute translation and rotation errors ---
trans_errors = []
rot_errors = []

for img_id, img_name, rvec_est, tvec_est, n_inliers in poses:
    gt_row = images_df[images_df["IMAGE_ID"] == img_id]
    if gt_row.empty:
        continue
    gt_row = gt_row.iloc[0]
    t_gt = np.array([gt_row.TX, gt_row.TY, gt_row.TZ], dtype=np.float64)

    # translation error
    t_err = np.linalg.norm(tvec_est - t_gt)
    trans_errors.append(t_err)

    # rotation error
    q_gt = np.array([gt_row.QW, gt_row.QX, gt_row.QY, gt_row.QZ], dtype=np.float64)
    R_gt = R.from_quat([q_gt[1], q_gt[2], q_gt[3], q_gt[0]]).as_matrix()
    R_est = cv2.Rodrigues(rvec_est)[0]
    R_diff = R.from_matrix(R_est @ R_gt.T)
    angle_err = np.degrees(np.linalg.norm(R_diff.as_rotvec()))
    rot_errors.append(angle_err)

# --- Print median errors ---
median_trans_error = np.median(trans_errors)
median_rot_error = np.median(rot_errors)*3.14/180

print(f"\nMedian translation error: {median_trans_error:.4f}")
print(f"Median rotation error: {median_rot_error:.4f} degrees")
# Out:
# Processing Image ID=164, Name=valid_img10.jpg
# Processing Image ID=165, Name=valid_img100.jpg
# R =  [[-0.07463316 -1.6116841   0.09964732]]      t =  [ 3.39176763 -0.42580698  1.9342243 ]
# Processing Image ID=166, Name=valid_img105.jpg
# R =  [[-0.94980925 -1.20714323 -0.46258651]]      t =  [ 1.84928547 -4.13922497  8.06545227]
# Processing Image ID=167, Name=valid_img110.jpg
# R =  [[-1.11026301 -1.03086851 -0.1141686 ]]      t =  [ 1.39417556 -4.20719086  7.6326883 ]
# Processing Image ID=168, Name=valid_img115.jpg
# R =  [[-0.05146592 -1.98516062 -0.70755623]]      t =  [ 4.09741264 -0.35790278  2.55925203]
# Processing Image ID=169, Name=valid_img120.jpg
# R =  [[-0.26877901 -1.65784164 -0.61271998]]      t =  [ 2.97814866 -0.85634446  2.0616095 ]
# Processing Image ID=170, Name=valid_img125.jpg
# R =  [[-0.93883171 -1.31364091  0.01814206]]      t =  [ 1.98690309 -3.947148    7.98855677]
# Processing Image ID=171, Name=valid_img130.jpg
# R =  [[-1.00145793 -1.21177825 -0.04094775]]      t =  [ 1.7523761  -3.72225808  7.13110763]
# Processing Image ID=172, Name=valid_img135.jpg
# R =  [[-0.8209791  -1.27193751 -0.13704191]]      t =  [ 2.6932673  -4.48404148 10.57794291]
# Processing Image ID=173, Name=valid_img140.jpg
# R =  [[-1.21661697 -0.9642163  -0.03510107]]      t =  [ 1.23284018 -4.48155231  7.69760293]
# Processing Image ID=174, Name=valid_img145.jpg
# R =  [[-1.24222385 -0.21232562 -0.07882831]]      t =  [-1.16082979 -3.23124874  6.66876503]
# Processing Image ID=175, Name=valid_img15.jpg
# R =  [[ 0.15447355  0.31900398 -0.33749284]]      t =  [3.4188078  0.06765586 0.67794166]
# Processing Image ID=176, Name=valid_img150.jpg
# R =  [[-1.46891195  0.32996508  0.41514356]]      t =  [-1.93871046 -4.31223305  7.51946815]
# Processing Image ID=177, Name=valid_img155.jpg
# R =  [[-0.14207912 -1.69334483 -0.15489612]]      t =  [ 3.56434404 -0.61201521  2.45269257]
# Processing Image ID=178, Name=valid_img160.jpg
# R =  [[-0.78201936 -1.44005788  0.0965341 ]]      t =  [ 1.15874896 -3.37886767  7.54462931]
# Processing Image ID=179, Name=valid_img165.jpg
# R =  [[-1.12513709 -1.02257566  0.18798655]]      t =  [ 2.00544854 -3.97811146  7.39975169]
# Processing Image ID=180, Name=valid_img170.jpg
# R =  [[-1.21595622 -0.81999261  0.15410869]]      t =  [ 1.19398324 -7.80931069 16.160186  ]
# Processing Image ID=181, Name=valid_img175.jpg
# R =  [[-1.04881837 -0.60688692 -0.40787111]]      t =  [ 0.96830287 -4.07387598  7.30342458]
# Processing Image ID=182, Name=valid_img180.jpg
# R =  [[-1.06777591 -1.2530542   0.29020448]]      t =  [ 1.11212716 -3.13834477  7.13339869]
# Processing Image ID=183, Name=valid_img185.jpg
# R =  [[-0.77850767 -1.46638746  0.29970175]]      t =  [ 1.92001319 -3.53862046  7.93887959]
# Processing Image ID=184, Name=valid_img190.jpg
# R =  [[-1.4309471  -1.20439691  0.61641761]]      t =  [ 1.36584275 -3.76918325  7.82183085]
# Processing Image ID=185, Name=valid_img195.jpg
# R =  [[-1.12709301 -0.34624315 -0.32304203]]      t =  [ 0.64086001 -3.92873442  6.99184548]
# Processing Image ID=186, Name=valid_img20.jpg
# R =  [[-0.39794634 -2.06740908 -0.19564725]]      t =  [ 4.04460896 -0.35171874  2.6729989 ]
# Processing Image ID=187, Name=valid_img200.jpg
# R =  [[-1.30643725 -1.44963141  0.44952512]]      t =  [ 0.99709696 -3.86272557  7.89962161]
# Processing Image ID=188, Name=valid_img205.jpg
# R =  [[-1.16843523 -0.50385826 -0.05758091]]      t =  [ 0.77837126 -4.24880823  7.50210862]
# Processing Image ID=189, Name=valid_img210.jpg
# R =  [[-1.18754603 -0.64251853  0.11759186]]      t =  [ 0.79279508 -4.25622557  7.52886458]
# Processing Image ID=190, Name=valid_img215.jpg
# R =  [[-1.58853817 -1.36121456  1.00467585]]      t =  [ 1.35812043 -2.82479736  7.35246119]
# Processing Image ID=191, Name=valid_img220.jpg
# R =  [[-1.28832641 -0.52706748  0.18636483]]      t =  [ 0.57636536 -4.01177866  7.15454034]
# Processing Image ID=192, Name=valid_img225.jpg
# R =  [[-1.41839475 -0.22772797  0.24373513]]      t =  [ 0.17267498 -4.62790699  7.88874977]
# Processing Image ID=193, Name=valid_img230.jpg
# R =  [[-1.10259007 -0.8086394  -0.03898886]]      t =  [ 0.54542239 -6.3504457  13.69026979]
# Processing Image ID=194, Name=valid_img235.jpg
# R =  [[-1.28095534  0.56413728  0.5020013 ]]      t =  [-0.64093334 -3.35539504  9.13857957]
# Processing Image ID=195, Name=valid_img240.jpg
# R =  [[-1.558341   -0.21666445  0.57058719]]      t =  [ 0.57663967 -4.41183776  8.49425708]
# Processing Image ID=196, Name=valid_img245.jpg
# R =  [[-1.35195773  0.45352519  0.5016849 ]]      t =  [-0.70085649 -3.19804147  9.08075664]
# Processing Image ID=197, Name=valid_img25.jpg
# R =  [[-0.28639762 -1.6967884  -0.15449344]]      t =  [ 3.66223104 -0.34984622  2.17929869]
# Processing Image ID=198, Name=valid_img250.jpg
# R =  [[-1.27755757 -0.4485567   0.36230507]]      t =  [-1.86449033e-03 -3.35867835e+00  7.52975205e+00]
# Processing Image ID=199, Name=valid_img255.jpg
# R =  [[-1.21275257  0.54828459  0.1066793 ]]      t =  [-1.04211481 -2.84785543  8.59114146]
# Processing Image ID=200, Name=valid_img260.jpg
# R =  [[-1.48480629 -0.10686974  0.65207003]]      t =  [ 0.19012678 -3.76932056  7.9001981 ]
# Processing Image ID=201, Name=valid_img265.jpg
# R =  [[-1.1794858   0.25736325  0.34314202]]      t =  [-0.12866931 -3.49718647  6.71638826]
# Processing Image ID=202, Name=valid_img270.jpg
# R =  [[-1.27729197 -0.72276215  0.46403602]]      t =  [ 0.73106633 -3.33316889  7.47925948]
# Processing Image ID=203, Name=valid_img275.jpg
# R =  [[-1.22455052 -0.31788319  0.55058685]]      t =  [ 0.64526353 -3.23373154  6.65408142]
# Processing Image ID=204, Name=valid_img280.jpg
# R =  [[-1.54561949 -0.43495202  0.85389193]]      t =  [ 1.33892907 -4.44673021  7.63411765]
# Processing Image ID=205, Name=valid_img285.jpg
# R =  [[-1.28625547 -0.08140138  0.48386477]]      t =  [ 0.68769983 -4.19260184  7.21010608]
# Processing Image ID=206, Name=valid_img290.jpg
# R =  [[-1.21465521  0.73288831  1.20658939]]      t =  [ 1.04297329 -4.97199634  9.84153869]
# Processing Image ID=207, Name=valid_img295.jpg
# R =  [[-1.40698034 -0.17970472  0.64982477]]      t =  [ 1.42184778 -4.22005541 10.72053652]
# Processing Image ID=208, Name=valid_img30.jpg
# R =  [[-1.55398547 -1.61750357 -0.16815568]]      t =  [-0.09323146 -2.57913075  4.48531249]
# Processing Image ID=209, Name=valid_img300.jpg
# R =  [[-1.31392641 -0.7480022   1.00798092]]      t =  [ 2.45912023 -3.98069875 12.35697211]
# Processing Image ID=210, Name=valid_img305.jpg
# R =  [[ 0.03170595 -0.64536838  0.09599693]]      t =  [ 0.61133461 -0.19591964  1.82614037]
# Processing Image ID=211, Name=valid_img310.jpg
# R =  [[-0.01134978 -0.59669625  0.1452219 ]]      t =  [ 0.69720597 -0.09856213  1.66595437]
# Processing Image ID=212, Name=valid_img315.jpg
# R =  [[-0.19603812 -1.33960311  0.52717989]]      t =  [ 2.26165381 -0.55468576  1.28734154]
# Processing Image ID=213, Name=valid_img320.jpg
# R =  [[ 0.01021148 -1.38491447  0.48248852]]      t =  [ 1.89300419 -0.00365452  1.36811976]
# Processing Image ID=214, Name=valid_img325.jpg
# R =  [[-0.573578    1.11815986 -0.04349013]]      t =  [-0.52266758 -0.50347019  1.7338081 ]
# Processing Image ID=215, Name=valid_img330.jpg
# R =  [[-0.37893976 -1.33165728  0.8290826 ]]      t =  [ 3.62484212 -2.95813949  7.35394773]
# Processing Image ID=216, Name=valid_img335.jpg
# R =  [[-0.01625298 -0.74791494  0.12127162]]      t =  [ 0.92841006 -0.28456155  1.86275206]
# Processing Image ID=217, Name=valid_img340.jpg
# R =  [[ 0.04116629 -0.61069667  0.19597164]]      t =  [0.77766747 0.03262059 1.81207017]
# Processing Image ID=218, Name=valid_img345.jpg
# R =  [[-1.06886167 -0.16103535  0.69552797]]      t =  [ 0.73568583 -0.78252345  1.85443598]
# Processing Image ID=219, Name=valid_img35.jpg
# R =  [[ 0.08999283 -1.59676397  0.03219312]]      t =  [ 3.39092186 -0.09062887  2.00553954]
# Processing Image ID=220, Name=valid_img350.jpg
# R =  [[-0.89772244  0.46494028  0.45817336]]      t =  [ 0.16973689 -0.88232779  1.65977941]
# Processing Image ID=221, Name=valid_img355.jpg
# R =  [[ 0.03624462 -0.54937067 -0.21226161]]      t =  [0.69660816 0.04734827 1.67901363]
# Processing Image ID=222, Name=valid_img360.jpg
# R =  [[-0.4850926  -0.49540347  0.01613919]]      t =  [ 0.73292309 -0.9273917   2.00572506]
# Processing Image ID=223, Name=valid_img365.jpg
# R =  [[-0.18770816 -0.60063404  0.11737084]]      t =  [ 0.84491199 -0.59891137  1.49744903]
# Processing Image ID=224, Name=valid_img370.jpg
# R =  [[-0.00091559 -0.30364055  0.04840914]]      t =  [ 0.43790737 -0.05035646  1.46241888]
# Processing Image ID=225, Name=valid_img375.jpg
# R =  [[-0.20153898 -0.31283276  0.07388401]]      t =  [ 0.63560318 -0.52304419  1.49209821]
# Processing Image ID=226, Name=valid_img380.jpg
# R =  [[-0.1124368  -0.08246794 -0.0253045 ]]      t =  [ 0.2292201  -0.51637811  1.50135853]
# Processing Image ID=227, Name=valid_img385.jpg
# R =  [[ 0.11585831 -0.00778001  0.10273218]]      t =  [-0.03826229  0.10971246  1.38462875]
# Processing Image ID=228, Name=valid_img390.jpg
# R =  [[-0.21489137 -0.05216768  0.0145093 ]]      t =  [ 0.06915259 -0.63037976  1.32841928]
# Processing Image ID=229, Name=valid_img395.jpg
# R =  [[-0.07411545  0.52407875  0.10138582]]      t =  [-1.08433368  0.13994105  1.39795716]
# Processing Image ID=230, Name=valid_img40.jpg
# R =  [[-0.23825253 -1.73198692 -0.41678536]]      t =  [ 3.94749475 -1.39976072  2.85764726]
# Processing Image ID=231, Name=valid_img400.jpg
# R =  [[-0.19240731  0.12406352  0.16682937]]      t =  [ 0.03993066 -0.57390437  1.74355606]
# Processing Image ID=232, Name=valid_img405.jpg
# R =  [[-0.45151718  0.43774286  0.30523818]]      t =  [-0.22704461 -0.99066075  1.80597659]
# Processing Image ID=233, Name=valid_img410.jpg
# R =  [[0.09202633 0.97674822 0.01408149]]      t =  [-1.81437757  0.22896948  1.41510635]
# Processing Image ID=234, Name=valid_img415.jpg
# R =  [[-0.03446641  1.15409478  0.03187429]]      t =  [-2.05721533  0.03422895  1.45749199]
# Processing Image ID=235, Name=valid_img420.jpg
# R =  [[-0.07554522  1.20946449 -0.12876214]]      t =  [-2.28173364  0.14160641  1.51201153]
# Processing Image ID=236, Name=valid_img425.jpg
# R =  [[-0.42873273  0.38595008  0.36544348]]      t =  [-0.19896556 -0.67473873  1.83244771]
# Processing Image ID=237, Name=valid_img430.jpg
# R =  [[0.09276189 1.61543039 0.10029391]]      t =  [-2.50247043  0.08110809  1.98636172]
# Processing Image ID=238, Name=valid_img435.jpg
# R =  [[0.14261986 1.76060776 0.20465412]]      t =  [-2.19284804 -0.16504058  2.28511605]
# Processing Image ID=239, Name=valid_img440.jpg
# R =  [[ 0.04908806  1.77590421 -0.1161346 ]]      t =  [-2.45486123  0.06614478  2.3092991 ]
# Processing Image ID=240, Name=valid_img445.jpg
# R =  [[-0.24062092  2.0814061  -0.09016788]]      t =  [-1.84609171 -0.34703867  3.7088147 ]
# Processing Image ID=241, Name=valid_img45.jpg
# R =  [[-0.18010173 -1.64213327 -0.22427152]]      t =  [ 3.15113482 -0.5004423   1.91696828]
# Processing Image ID=242, Name=valid_img450.jpg
# R =  [[ 0.22396884  2.24166468 -0.0301014 ]]      t =  [-2.33374908  0.10250151  2.80277437]
# Processing Image ID=243, Name=valid_img455.jpg
# R =  [[0.45688986 2.01269203 0.50050699]]      t =  [-1.88318205 -0.16376947  3.87495312]
# Processing Image ID=244, Name=valid_img460.jpg
# R =  [[0.17711395 2.03449554 0.26379713]]      t =  [-1.72663636 -0.5128698   3.83214541]
# Processing Image ID=245, Name=valid_img465.jpg
# R =  [[0.48079472 2.00760005 0.19838954]]      t =  [-1.939273    0.12461379  3.49196117]
# Processing Image ID=246, Name=valid_img470.jpg
# R =  [[-0.65981239  1.90577197 -0.219028  ]]      t =  [-1.65165402 -0.12705072  4.40034312]
# Processing Image ID=247, Name=valid_img475.jpg
# R =  [[ 0.10831052  2.45603719 -0.27469642]]      t =  [-2.01193275  0.16561966  3.24876054]
# Processing Image ID=248, Name=valid_img480.jpg
# R =  [[-0.16870263 -0.49342814  0.52947428]]      t =  [ 1.07376391 -0.31310165  4.57778446]
# Processing Image ID=249, Name=valid_img485.jpg
# R =  [[ 0.14133196  2.27271147 -0.22876445]]      t =  [-2.10439818  0.20124028  3.33655952]
# Processing Image ID=250, Name=valid_img490.jpg
# R =  [[ 0.26905314 -0.0181647  -0.03500428]]      t =  [ 0.47316746 -0.48664242  3.88503829]
# Processing Image ID=251, Name=valid_img495.jpg
# R =  [[ 0.00190539 -0.91246454  0.67688329]]      t =  [ 1.42489184 -0.82002786  3.45268486]
# Processing Image ID=252, Name=valid_img5.jpg
# R =  [[-0.35512746 -1.69364331 -0.30630663]]      t =  [ 3.77406403 -0.33273749  2.05073271]
# Processing Image ID=253, Name=valid_img50.jpg
# R =  [[-0.18166239 -1.7186823  -0.07817507]]      t =  [ 3.41638002 -0.45439254  2.05807633]
# Processing Image ID=254, Name=valid_img500.jpg
# R =  [[0.01245614 0.29967972 0.04600288]]      t =  [-0.17293458 -0.22723761  2.59065644]
# Processing Image ID=255, Name=valid_img505.jpg
# R =  [[ 0.36985047 -0.21593719 -0.26491113]]      t =  [ 0.64242574 -0.20036233  3.61388996]
# Processing Image ID=256, Name=valid_img510.jpg
# R =  [[ 0.14188405 -0.30221475 -0.35549598]]      t =  [ 0.78951865 -0.62323344  3.3365231 ]
# Processing Image ID=257, Name=valid_img515.jpg
# R =  [[0.12584586 0.1037292  0.15325256]]      t =  [-0.17565917 -0.38205885  2.90239951]
# Processing Image ID=258, Name=valid_img520.jpg
# R =  [[ 0.19622246  0.20879476 -0.2255822 ]]      t =  [ 0.3550644  -0.41180324  3.41019137]
# Processing Image ID=259, Name=valid_img525.jpg
# R =  [[0.16808505 0.49783465 0.2809956 ]]      t =  [-0.46936726  0.20546135  2.78832122]
# Processing Image ID=260, Name=valid_img530.jpg
# R =  [[-0.06741256  0.48194921  0.29562407]]      t =  [-0.34407674 -0.30281498  3.20607874]
# Processing Image ID=261, Name=valid_img535.jpg
# R =  [[-0.24433064  0.51219181  0.3618791 ]]      t =  [-0.25871021 -0.58452163  3.49178031]
# Processing Image ID=262, Name=valid_img540.jpg
# R =  [[ 0.30938741  0.44844549 -0.09470209]]      t =  [-0.05859148  0.08387062  3.71777675]
# Processing Image ID=263, Name=valid_img545.jpg
# R =  [[-0.41633082 -0.53894348  0.41253873]]      t =  [ 1.18601563 -0.78548944  3.93017507]
# Processing Image ID=264, Name=valid_img55.jpg
# R =  [[-1.05915072 -0.82088624 -0.46366376]]      t =  [-0.04737451 -2.65456351  3.19356426]
# Processing Image ID=265, Name=valid_img550.jpg
# R =  [[-0.53029468 -0.02822447  0.19842811]]      t =  [ 0.34080189 -1.32654426  3.08458099]
# Processing Image ID=266, Name=valid_img555.jpg
# R =  [[-0.39556698  0.34544598  0.73705644]]      t =  [-0.10412099 -0.84048271  3.92721154]
# Processing Image ID=267, Name=valid_img560.jpg
# R =  [[-0.36430689  0.34470193  0.78227821]]      t =  [ 0.13643468 -0.5091346   3.94708944]
# Processing Image ID=268, Name=valid_img565.jpg
# R =  [[-0.00967355  0.10811138  0.22674677]]      t =  [ 0.198605   -0.34587546  3.9142717 ]
# Processing Image ID=269, Name=valid_img570.jpg
# R =  [[-0.25987277  0.24934437  0.3521722 ]]      t =  [ 0.03744349 -0.78578085  4.00625343]
# Processing Image ID=270, Name=valid_img575.jpg
# R =  [[ 0.10291888  0.28174738 -0.06567207]]      t =  [ 0.24737673 -0.48134535  4.57763026]
# Processing Image ID=271, Name=valid_img580.jpg
# R =  [[-0.52968394  0.68751359  0.60766551]]      t =  [-0.11329642 -1.02972505  4.9360436 ]
# Processing Image ID=272, Name=valid_img585.jpg
# R =  [[ 0.49345791 -0.06799792  0.49244003]]      t =  [0.45206803 0.43980828 4.9112785 ]
# Processing Image ID=273, Name=valid_img590.jpg
# R =  [[-0.28228935 -0.06229365  0.20791952]]      t =  [ 0.58210296 -1.0389495   4.74526334]
# Processing Image ID=274, Name=valid_img595.jpg
# R =  [[-0.0960811   0.20986276  0.61919234]]      t =  [ 0.12229216 -0.35113457  4.68662981]
# Processing Image ID=275, Name=valid_img60.jpg
# R =  [[ 0.19525796 -1.55921178  0.09852719]]      t =  [3.25925788 0.08175276 1.85021111]
# Processing Image ID=276, Name=valid_img600.jpg
# R =  [[-0.2045148   0.39715671  0.61390563]]      t =  [-2.28738074e-03 -3.53146135e-01  5.02457222e+00]
# Processing Image ID=277, Name=valid_img605.jpg
# R =  [[-0.19717846 -0.62049269  0.59827931]]      t =  [ 1.63665626 -0.74904013  6.23806121]
# Processing Image ID=278, Name=valid_img610.jpg
# R =  [[-0.25569655  0.46263921  0.56513846]]      t =  [-0.14996198 -0.74442616  5.19802132]
# Processing Image ID=279, Name=valid_img615.jpg
# R =  [[ 0.21424564  0.20571554 -0.24505822]]      t =  [ 0.40141965 -0.5569894   4.76351552]
# Processing Image ID=280, Name=valid_img620.jpg
# R =  [[-0.64453917  0.19330163  1.13481915]]      t =  [ 1.04045708 -0.97827669  5.43960666]
# Processing Image ID=281, Name=valid_img625.jpg
# R =  [[-0.6180793   0.41152218  0.98931553]]      t =  [ 0.78501518 -1.30993103  6.08560628]
# Processing Image ID=282, Name=valid_img630.jpg
# R =  [[-0.621748    0.32971281  0.75579948]]      t =  [ 0.98358811 -1.47275064  6.39843548]
# Processing Image ID=283, Name=valid_img635.jpg
# R =  [[-0.6341283  0.5302147  0.830988 ]]      t =  [ 0.88695686 -1.82731864  6.24410608]
# Processing Image ID=284, Name=valid_img640.jpg
# R =  [[ 1.0656759  -2.84324973 -0.59487255]]      t =  [ 0.98213131 -1.27080836  8.13026313]
# Processing Image ID=285, Name=valid_img645.jpg
# R =  [[ 0.12066487 -0.52281002  0.61552742]]      t =  [ 1.26009814 -0.31378471  6.14124697]
# Processing Image ID=286, Name=valid_img65.jpg
# R =  [[-1.02442128 -0.22584321 -0.39547224]]      t =  [-0.78441268 -3.00057822  3.06656306]
# Processing Image ID=287, Name=valid_img650.jpg
# R =  [[-0.39728443  0.6898174   0.83819616]]      t =  [-0.03060063 -1.05695235  5.97642534]
# Processing Image ID=288, Name=valid_img70.jpg
# R =  [[-0.01111601 -2.01172905  0.15246472]]      t =  [ 3.47317169 -0.0552437   2.37046314]
# Processing Image ID=289, Name=valid_img75.jpg
# R =  [[-0.21992121 -1.51290963 -0.0829838 ]]      t =  [ 3.05833595 -0.65637456  1.70986578]
# Processing Image ID=290, Name=valid_img80.jpg
# R =  [[-0.03468652 -1.5298743   0.00426109]]      t =  [ 3.04738374 -0.25105567  1.57956271]
# Processing Image ID=291, Name=valid_img85.jpg
# R =  [[-0.13967698 -1.59084282 -0.03458769]]      t =  [ 2.87233797 -0.34847849  1.62662343]
# Processing Image ID=292, Name=valid_img90.jpg
# R =  [[-0.37928163 -1.85092994 -0.2167924 ]]      t =  [3.22701122 0.01697224 1.75525771]
# Processing Image ID=293, Name=valid_img95.jpg
# R =  [[-1.05693083 -1.27500447  0.02612954]]      t =  [ 2.0381306  -3.53670269  7.45800732]
#
# Median translation error: 6.1736
# Median rotation error: 1.6696 degrees
