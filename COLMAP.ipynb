# %% [markdown]
# # **Q1 - Camera Relocalization**

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
import subprocess

# Data and project path
video_path = "/content/drive/MyDrive/3DCV/HW2/COLMAP/Sinica.mp4"
workspace_dir = "/content/drive/MyDrive/3DCV/HW2/COLMAP"

# Creating folders
frames_dir = os.path.join(workspace_dir, "frames")
database_dir = os.path.join(workspace_dir, "database")
output_dir = os.path.join(workspace_dir, "output")

os.makedirs(frames_dir, exist_ok=True)
os.makedirs(database_dir, exist_ok=True)
os.makedirs(output_dir, exist_ok=True)

print(" Google Drive mounted successfully")
print(f"Video path: {video_path}")
print(f"Frames will be saved to: {frames_dir}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#  Google Drive mounted successfully
# Video path: /content/drive/MyDrive/3DCV/HW2/COLMAP/Sinica.mp4
# Frames will be saved to: /content/drive/MyDrive/3DCV/HW2/COLMAP/frames

# %% [markdown]
# **Installing COLMAP**

# %%
# Install colmap
# !apt-get install -y colmap ffmpeg

# !colmap --version

print(" COLMAP and FFmpeg installed successfully")
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# colmap is already the newest version (3.7-2).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.
# ERROR: Command `--version` not recognized. To list the available commands, run `colmap help`.
#  COLMAP and FFmpeg installed successfully

# %% [markdown]
# Extracting Frames fps=10
#
# Totally 368 frames

# %%
# Cheking Video
if os.path.exists(video_path):
    print(f" Video file found: {video_path}")

    # Extracting Frames FPS=10
    cmd = f'ffmpeg -i "{video_path}" -vf "fps=10" "{frames_dir}/frame_%04d.jpg" -hide_banner'
    # !{cmd}


    frame_files = [f for f in os.listdir(frames_dir) if f.endswith('.jpg')]
    print(f" Extracted {len(frame_files)} frames to: {frames_dir}")


    if frame_files:
        print("Sample frames:", frame_files[:5])
else:
    print(f" Video file not found: {video_path}")
# Out:
#  Video file found: /content/drive/MyDrive/3DCV/HW2/COLMAP/Sinica.mp4
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/drive/MyDrive/3DCV/HW2/COLMAP/Sinica.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2025-10-08T09:15:37.000000Z
#     com.android.version: 13
#     com.android.manufacturer: Xiaomi
#     com.android.model: 2201117TG
#     com.xiaomi.product.marketname: Redmi Note 11
#   Duration: 00:00:36.76, start: 0.000000, bitrate: 14341 kb/s
#   Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuvj420p(pc, bt470bg/bt470bg/smpte170m), 1280x720, 13978 kb/s, 29.77 fps, 30.26 tbr, 90k tbn, 180k tbc (default)
#     Metadata:
#       rotate          : 90
#       creation_time   : 2025-10-08T09:15:37.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#     Side data:
#       displaymatrix: rotation of -90.00 degrees
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 192 kb/s (default)
#     Metadata:
#       creation_time   : 2025-10-08T09:15:37.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/content/drive/MyDrive/3DCV/HW2/COLMAP/frames/frame_%04d.jpg':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     com.xiaomi.product.marketname: Redmi Note 11
#     com.android.version: 13
#     com.android.manufacturer: Xiaomi
#     com.android.model: 2201117TG
#     encoder         : Lavf58.76.100
#   Stream #0:0(eng): Video: mjpeg, yuvj420p(pc, bt470bg/bt470bg/smpte170m, progressive), 720x1280, q=2-31, 200 kb/s, 10 fps, 10 tbn (default)
#     Metadata:
#       encoder         : Lavc58.134.100 mjpeg
#       creation_time   : 2025-10-08T09:15:37.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
#       displaymatrix: rotation of -0.00 degrees
# frame=  368 fps= 22 q=24.8 Lsize=N/A time=00:00:36.80 bitrate=N/A dup=1 drop=0 speed= 2.2x
# video:12849kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
#  Extracted 368 frames to: /content/drive/MyDrive/3DCV/HW2/COLMAP/frames
# Sample frames: ['frame_0001.jpg', 'frame_0003.jpg', 'frame_0004.jpg', 'frame_0006.jpg', 'frame_0007.jpg']

# %%
    frame_files = [f for f in os.listdir(frames_dir) if f.endswith('.jpg')]
    print(f" Extracted {len(frame_files)} frames to: {frames_dir}")
# Out:
#  Extracted 368 frames to: /content/drive/MyDrive/3DCV/HW2/COLMAP/frames

# %%
import os
os.environ['QT_QPA_PLATFORM'] = 'offscreen'

workspace_dir = "/content/drive/MyDrive/3DCV/HW2/COLMAP"
frames_dir = f"{workspace_dir}/frames"
database_path = f"{workspace_dir}/database/database.db"
output_dir = f"{workspace_dir}/output"

# Database folder
os.makedirs(f"{workspace_dir}/database", exist_ok=True)
os.makedirs(output_dir, exist_ok=True)

print(" Environment setup completed")
# Out:
#  Environment setup completed

# %% [markdown]
# # **Feature Extraction**

# %%
import os
# database_path = f"{workspace_dir}/database/database.db"
# if os.path.exists(database_path):
#     os.remove(database_path)
#     print(" Old database removed")

# Feature extracting
# !colmap feature_extractor \
   --database_path "{database_path}" \
   --image_path "{frames_dir}" \
   --ImageReader.single_camera 1 \
   --SiftExtraction.use_gpu=false  # CPU

print(" Feature extraction with CPU completed")
# Out:
# WARNING: Your current options use the maximum number of threads on the machine to extract features. Exracting SIFT features on the CPU can consume a lot of RAM per thread for large images. Consider reducing the maximum image size and/or the first octave or manually limit the number of extraction threads. Ignore this warning, if your machine has sufficient memory for the current settings.
#
# ==============================================================================
# Feature extraction
# ==============================================================================
#
# Processed file [1/368]
#   Name:            frame_0001.jpg
#   SKIP: Features for image already extracted.
# Processed file [2/368]
#   Name:            frame_0002.jpg
#   SKIP: Features for image already extracted.
# Processed file [3/368]
#   Name:            frame_0003.jpg
#   SKIP: Features for image already extracted.
# Processed file [4/368]
#   Name:            frame_0004.jpg
#   SKIP: Features for image already extracted.
# Processed file [5/368]
#   Name:            frame_0005.jpg
#   SKIP: Features for image already extracted.
# Processed file [6/368]
#   Name:            frame_0006.jpg
#   SKIP: Features for image already extracted.
# Processed file [7/368]
#   Name:            frame_0007.jpg
#   SKIP: Features for image already extracted.
# Processed file [8/368]
#   Name:            frame_0008.jpg
#   SKIP: Features for image already extracted.
# Processed file [9/368]
#   Name:            frame_0009.jpg
#   SKIP: Features for image already extracted.
# Processed file [10/368]
#   Name:            frame_0010.jpg
#   SKIP: Features for image already extracted.
# Processed file [11/368]
#   Name:            frame_0011.jpg
#   SKIP: Features for image already extracted.
# Processed file [12/368]
#   Name:            frame_0012.jpg
#   SKIP: Features for image already extracted.
# Processed file [13/368]
#   Name:            frame_0013.jpg
#   SKIP: Features for image already extracted.
# Processed file [14/368]
#   Name:            frame_0014.jpg
#   SKIP: Features for image already extracted.
# Processed file [15/368]
#   Name:            frame_0015.jpg
#   SKIP: Features for image already extracted.
# Processed file [16/368]
#   Name:            frame_0016.jpg
#   SKIP: Features for image already extracted.
# Processed file [17/368]
#   Name:            frame_0017.jpg
#   SKIP: Features for image already extracted.
# Processed file [18/368]
#   Name:            frame_0018.jpg
#   SKIP: Features for image already extracted.
# Processed file [19/368]
#   Name:            frame_0019.jpg
#   SKIP: Features for image already extracted.
# Processed file [20/368]
#   Name:            frame_0020.jpg
#   SKIP: Features for image already extracted.
# Processed file [21/368]
#   Name:            frame_0021.jpg
#   SKIP: Features for image already extracted.
# Processed file [22/368]
#   Name:            frame_0022.jpg
#   SKIP: Features for image already extracted.
# Processed file [23/368]
#   Name:            frame_0023.jpg
#   SKIP: Features for image already extracted.
# Processed file [24/368]
#   Name:            frame_0024.jpg
#   SKIP: Features for image already extracted.
# Processed file [25/368]
#   Name:            frame_0025.jpg
#   SKIP: Features for image already extracted.
# Processed file [26/368]
#   Name:            frame_0026.jpg
#   SKIP: Features for image already extracted.
# Processed file [27/368]
#   Name:            frame_0027.jpg
#   SKIP: Features for image already extracted.
# Processed file [28/368]
#   Name:            frame_0028.jpg
#   SKIP: Features for image already extracted.
# Processed file [29/368]
#   Name:            frame_0029.jpg
#   SKIP: Features for image already extracted.
# Processed file [30/368]
#   Name:            frame_0030.jpg
#   SKIP: Features for image already extracted.
# Processed file [31/368]
#   Name:            frame_0031.jpg
#   SKIP: Features for image already extracted.
# Processed file [32/368]
#   Name:            frame_0032.jpg
#   SKIP: Features for image already extracted.
# Processed file [33/368]
#   Name:            frame_0033.jpg
#   SKIP: Features for image already extracted.
# Processed file [34/368]
#   Name:            frame_0034.jpg
#   SKIP: Features for image already extracted.
# Processed file [35/368]
#   Name:            frame_0035.jpg
#   SKIP: Features for image already extracted.
# Processed file [36/368]
#   Name:            frame_0036.jpg
#   SKIP: Features for image already extracted.
# Processed file [37/368]
#   Name:            frame_0037.jpg
#   SKIP: Features for image already extracted.
# Processed file [38/368]
#   Name:            frame_0038.jpg
#   SKIP: Features for image already extracted.
# Processed file [39/368]
#   Name:            frame_0039.jpg
#   SKIP: Features for image already extracted.
# Processed file [40/368]
#   Name:            frame_0040.jpg
#   SKIP: Features for image already extracted.
# Processed file [41/368]
#   Name:            frame_0041.jpg
#   SKIP: Features for image already extracted.
# Processed file [42/368]
#   Name:            frame_0042.jpg
#   SKIP: Features for image already extracted.
# Processed file [43/368]
#   Name:            frame_0043.jpg
#   SKIP: Features for image already extracted.
# Processed file [44/368]
#   Name:            frame_0044.jpg
#   SKIP: Features for image already extracted.
# Processed file [45/368]
#   Name:            frame_0045.jpg
#   SKIP: Features for image already extracted.
# Processed file [46/368]
#   Name:            frame_0046.jpg
#   SKIP: Features for image already extracted.
# Processed file [47/368]
#   Name:            frame_0047.jpg
#   SKIP: Features for image already extracted.
# Processed file [48/368]
#   Name:            frame_0048.jpg
#   SKIP: Features for image already extracted.
# Processed file [49/368]
#   Name:            frame_0049.jpg
#   SKIP: Features for image already extracted.
# Processed file [50/368]
#   Name:            frame_0050.jpg
#   SKIP: Features for image already extracted.
# Processed file [51/368]
#   Name:            frame_0051.jpg
#   SKIP: Features for image already extracted.
# Processed file [52/368]
#   Name:            frame_0052.jpg
#   SKIP: Features for image already extracted.
# Processed file [53/368]
#   Name:            frame_0053.jpg
#   SKIP: Features for image already extracted.
# Processed file [54/368]
#   Name:            frame_0054.jpg
#   SKIP: Features for image already extracted.
# Processed file [55/368]
#   Name:            frame_0055.jpg
#   SKIP: Features for image already extracted.
# Processed file [56/368]
#   Name:            frame_0056.jpg
#   SKIP: Features for image already extracted.
# Processed file [57/368]
#   Name:            frame_0057.jpg
#   SKIP: Features for image already extracted.
# Processed file [58/368]
#   Name:            frame_0058.jpg
#   SKIP: Features for image already extracted.
# Processed file [59/368]
#   Name:            frame_0059.jpg
#   SKIP: Features for image already extracted.
# Processed file [60/368]
#   Name:            frame_0060.jpg
#   SKIP: Features for image already extracted.
# Processed file [61/368]
#   Name:            frame_0061.jpg
#   SKIP: Features for image already extracted.
# Processed file [62/368]
#   Name:            frame_0062.jpg
#   SKIP: Features for image already extracted.
# Processed file [63/368]
#   Name:            frame_0063.jpg
#   SKIP: Features for image already extracted.
# Processed file [64/368]
#   Name:            frame_0064.jpg
#   SKIP: Features for image already extracted.
# Processed file [65/368]
#   Name:            frame_0065.jpg
#   SKIP: Features for image already extracted.
# Processed file [66/368]
#   Name:            frame_0066.jpg
#   SKIP: Features for image already extracted.
# Processed file [67/368]
#   Name:            frame_0067.jpg
#   SKIP: Features for image already extracted.
# Processed file [68/368]
#   Name:            frame_0068.jpg
#   SKIP: Features for image already extracted.
# Processed file [69/368]
#   Name:            frame_0069.jpg
#   SKIP: Features for image already extracted.
# Processed file [70/368]
#   Name:            frame_0070.jpg
#   SKIP: Features for image already extracted.
# Processed file [71/368]
#   Name:            frame_0071.jpg
#   SKIP: Features for image already extracted.
# Processed file [72/368]
#   Name:            frame_0072.jpg
#   SKIP: Features for image already extracted.
# Processed file [73/368]
#   Name:            frame_0073.jpg
#   SKIP: Features for image already extracted.
# Processed file [74/368]
#   Name:            frame_0074.jpg
#   SKIP: Features for image already extracted.
# Processed file [75/368]
#   Name:            frame_0075.jpg
#   SKIP: Features for image already extracted.
# Processed file [76/368]
#   Name:            frame_0076.jpg
#   SKIP: Features for image already extracted.
# Processed file [77/368]
#   Name:            frame_0077.jpg
#   SKIP: Features for image already extracted.
# Processed file [78/368]
#   Name:            frame_0078.jpg
#   SKIP: Features for image already extracted.
# Processed file [79/368]
#   Name:            frame_0079.jpg
#   SKIP: Features for image already extracted.
# Processed file [80/368]
#   Name:            frame_0080.jpg
#   SKIP: Features for image already extracted.
# Processed file [81/368]
#   Name:            frame_0081.jpg
#   SKIP: Features for image already extracted.
# Processed file [82/368]
#   Name:            frame_0082.jpg
#   SKIP: Features for image already extracted.
# Processed file [83/368]
#   Name:            frame_0083.jpg
#   SKIP: Features for image already extracted.
# Processed file [84/368]
#   Name:            frame_0084.jpg
#   SKIP: Features for image already extracted.
# Processed file [85/368]
#   Name:            frame_0085.jpg
#   SKIP: Features for image already extracted.
# Processed file [86/368]
#   Name:            frame_0086.jpg
#   SKIP: Features for image already extracted.
# Processed file [87/368]
#   Name:            frame_0087.jpg
#   SKIP: Features for image already extracted.
# Processed file [88/368]
#   Name:            frame_0088.jpg
#   SKIP: Features for image already extracted.
# Processed file [89/368]
#   Name:            frame_0089.jpg
#   SKIP: Features for image already extracted.
# Processed file [90/368]
#   Name:            frame_0090.jpg
#   SKIP: Features for image already extracted.
# Processed file [91/368]
#   Name:            frame_0091.jpg
#   SKIP: Features for image already extracted.
# Processed file [92/368]
#   Name:            frame_0092.jpg
#   SKIP: Features for image already extracted.
# Processed file [93/368]
#   Name:            frame_0093.jpg
#   SKIP: Features for image already extracted.
# Processed file [94/368]
#   Name:            frame_0094.jpg
#   SKIP: Features for image already extracted.
# Processed file [95/368]
#   Name:            frame_0095.jpg
#   SKIP: Features for image already extracted.
# Processed file [96/368]
#   Name:            frame_0096.jpg
#   SKIP: Features for image already extracted.
# Processed file [97/368]
#   Name:            frame_0097.jpg
#   SKIP: Features for image already extracted.
# Processed file [98/368]
#   Name:            frame_0098.jpg
#   SKIP: Features for image already extracted.
# Processed file [99/368]
#   Name:            frame_0099.jpg
#   SKIP: Features for image already extracted.
# Processed file [100/368]
#   Name:            frame_0100.jpg
#   SKIP: Features for image already extracted.
# Processed file [101/368]
#   Name:            frame_0101.jpg
#   SKIP: Features for image already extracted.
# Processed file [102/368]
#   Name:            frame_0102.jpg
#   SKIP: Features for image already extracted.
# Processed file [103/368]
#   Name:            frame_0103.jpg
#   SKIP: Features for image already extracted.
# Processed file [104/368]
#   Name:            frame_0104.jpg
#   SKIP: Features for image already extracted.
# Processed file [105/368]
#   Name:            frame_0105.jpg
#   SKIP: Features for image already extracted.
# Processed file [106/368]
#   Name:            frame_0106.jpg
#   SKIP: Features for image already extracted.
# Processed file [107/368]
#   Name:            frame_0107.jpg
#   SKIP: Features for image already extracted.
# Processed file [108/368]
#   Name:            frame_0108.jpg
#   SKIP: Features for image already extracted.
# Processed file [109/368]
#   Name:            frame_0109.jpg
#   SKIP: Features for image already extracted.
# Processed file [110/368]
#   Name:            frame_0110.jpg
#   SKIP: Features for image already extracted.
# Processed file [111/368]
#   Name:            frame_0111.jpg
#   SKIP: Features for image already extracted.
# Processed file [112/368]
#   Name:            frame_0112.jpg
#   SKIP: Features for image already extracted.
# Processed file [113/368]
#   Name:            frame_0113.jpg
#   SKIP: Features for image already extracted.
# Processed file [114/368]
#   Name:            frame_0114.jpg
#   SKIP: Features for image already extracted.
# Processed file [115/368]
#   Name:            frame_0115.jpg
#   SKIP: Features for image already extracted.
# Processed file [116/368]
#   Name:            frame_0116.jpg
#   SKIP: Features for image already extracted.
# Processed file [117/368]
#   Name:            frame_0117.jpg
#   SKIP: Features for image already extracted.
# Processed file [118/368]
#   Name:            frame_0118.jpg
#   SKIP: Features for image already extracted.
# Processed file [119/368]
#   Name:            frame_0119.jpg
#   SKIP: Features for image already extracted.
# Processed file [120/368]
#   Name:            frame_0120.jpg
#   SKIP: Features for image already extracted.
# Processed file [121/368]
#   Name:            frame_0121.jpg
#   SKIP: Features for image already extracted.
# Processed file [122/368]
#   Name:            frame_0122.jpg
#   SKIP: Features for image already extracted.
# Processed file [123/368]
#   Name:            frame_0123.jpg
#   SKIP: Features for image already extracted.
# Processed file [124/368]
#   Name:            frame_0124.jpg
#   SKIP: Features for image already extracted.
# Processed file [125/368]
#   Name:            frame_0125.jpg
#   SKIP: Features for image already extracted.
# Processed file [126/368]
#   Name:            frame_0126.jpg
#   SKIP: Features for image already extracted.
# Processed file [127/368]
#   Name:            frame_0127.jpg
#   SKIP: Features for image already extracted.
# Processed file [128/368]
#   Name:            frame_0128.jpg
#   SKIP: Features for image already extracted.
# Processed file [129/368]
#   Name:            frame_0129.jpg
#   SKIP: Features for image already extracted.
# Processed file [130/368]
#   Name:            frame_0130.jpg
#   SKIP: Features for image already extracted.
# Processed file [131/368]
#   Name:            frame_0131.jpg
#   SKIP: Features for image already extracted.
# Processed file [132/368]
#   Name:            frame_0132.jpg
#   SKIP: Features for image already extracted.
# Processed file [133/368]
#   Name:            frame_0133.jpg
#   SKIP: Features for image already extracted.
# Processed file [134/368]
#   Name:            frame_0134.jpg
#   SKIP: Features for image already extracted.
# Processed file [135/368]
#   Name:            frame_0135.jpg
#   SKIP: Features for image already extracted.
# Processed file [136/368]
#   Name:            frame_0136.jpg
#   SKIP: Features for image already extracted.
# Processed file [137/368]
#   Name:            frame_0137.jpg
#   SKIP: Features for image already extracted.
# Processed file [138/368]
#   Name:            frame_0138.jpg
#   SKIP: Features for image already extracted.
# Processed file [139/368]
#   Name:            frame_0139.jpg
#   SKIP: Features for image already extracted.
# Processed file [140/368]
#   Name:            frame_0140.jpg
#   SKIP: Features for image already extracted.
# Processed file [141/368]
#   Name:            frame_0141.jpg
#   SKIP: Features for image already extracted.
# Processed file [142/368]
#   Name:            frame_0142.jpg
#   SKIP: Features for image already extracted.
# Processed file [143/368]
#   Name:            frame_0143.jpg
#   SKIP: Features for image already extracted.
# Processed file [144/368]
#   Name:            frame_0144.jpg
#   SKIP: Features for image already extracted.
# Processed file [145/368]
#   Name:            frame_0145.jpg
#   SKIP: Features for image already extracted.
# Processed file [146/368]
#   Name:            frame_0146.jpg
#   SKIP: Features for image already extracted.
# Processed file [147/368]
#   Name:            frame_0147.jpg
#   SKIP: Features for image already extracted.
# Processed file [148/368]
#   Name:            frame_0148.jpg
#   SKIP: Features for image already extracted.
# Processed file [149/368]
#   Name:            frame_0149.jpg
#   SKIP: Features for image already extracted.
# Processed file [150/368]
#   Name:            frame_0150.jpg
#   SKIP: Features for image already extracted.
# Processed file [151/368]
#   Name:            frame_0151.jpg
#   SKIP: Features for image already extracted.
# Processed file [152/368]
#   Name:            frame_0152.jpg
#   SKIP: Features for image already extracted.
# Processed file [153/368]
#   Name:            frame_0153.jpg
#   SKIP: Features for image already extracted.
# Processed file [154/368]
#   Name:            frame_0154.jpg
#   SKIP: Features for image already extracted.
# Processed file [155/368]
#   Name:            frame_0155.jpg
#   SKIP: Features for image already extracted.
# Processed file [156/368]
#   Name:            frame_0156.jpg
#   SKIP: Features for image already extracted.
# Processed file [157/368]
#   Name:            frame_0157.jpg
#   SKIP: Features for image already extracted.
# Processed file [158/368]
#   Name:            frame_0158.jpg
#   SKIP: Features for image already extracted.
# Processed file [159/368]
#   Name:            frame_0159.jpg
#   SKIP: Features for image already extracted.
# Processed file [160/368]
#   Name:            frame_0160.jpg
#   SKIP: Features for image already extracted.
# Processed file [161/368]
#   Name:            frame_0161.jpg
#   SKIP: Features for image already extracted.
# Processed file [162/368]
#   Name:            frame_0162.jpg
#   SKIP: Features for image already extracted.
# Processed file [163/368]
#   Name:            frame_0163.jpg
#   SKIP: Features for image already extracted.
# Processed file [164/368]
#   Name:            frame_0164.jpg
#   SKIP: Features for image already extracted.
# Processed file [165/368]
#   Name:            frame_0165.jpg
#   SKIP: Features for image already extracted.
# Processed file [166/368]
#   Name:            frame_0166.jpg
#   SKIP: Features for image already extracted.
# Processed file [167/368]
#   Name:            frame_0167.jpg
#   SKIP: Features for image already extracted.
# Processed file [168/368]
#   Name:            frame_0168.jpg
#   SKIP: Features for image already extracted.
# Processed file [169/368]
#   Name:            frame_0169.jpg
#   SKIP: Features for image already extracted.
# Processed file [170/368]
#   Name:            frame_0170.jpg
#   SKIP: Features for image already extracted.
# Processed file [171/368]
#   Name:            frame_0171.jpg
#   SKIP: Features for image already extracted.
# Processed file [172/368]
#   Name:            frame_0172.jpg
#   SKIP: Features for image already extracted.
# Processed file [173/368]
#   Name:            frame_0173.jpg
#   SKIP: Features for image already extracted.
# Processed file [174/368]
#   Name:            frame_0174.jpg
#   SKIP: Features for image already extracted.
# Processed file [175/368]
#   Name:            frame_0175.jpg
#   SKIP: Features for image already extracted.
# Processed file [176/368]
#   Name:            frame_0176.jpg
#   SKIP: Features for image already extracted.
# Processed file [177/368]
#   Name:            frame_0177.jpg
#   SKIP: Features for image already extracted.
# Processed file [178/368]
#   Name:            frame_0178.jpg
#   SKIP: Features for image already extracted.
# Processed file [179/368]
#   Name:            frame_0179.jpg
#   SKIP: Features for image already extracted.
# Processed file [180/368]
#   Name:            frame_0180.jpg
#   SKIP: Features for image already extracted.
# Processed file [181/368]
#   Name:            frame_0181.jpg
#   SKIP: Features for image already extracted.
# Processed file [182/368]
#   Name:            frame_0182.jpg
#   SKIP: Features for image already extracted.
# Processed file [183/368]
#   Name:            frame_0183.jpg
#   SKIP: Features for image already extracted.
# Processed file [184/368]
#   Name:            frame_0184.jpg
#   SKIP: Features for image already extracted.
# Processed file [185/368]
#   Name:            frame_0185.jpg
#   SKIP: Features for image already extracted.
# Processed file [186/368]
#   Name:            frame_0186.jpg
#   SKIP: Features for image already extracted.
# Processed file [187/368]
#   Name:            frame_0187.jpg
#   SKIP: Features for image already extracted.
# Processed file [188/368]
#   Name:            frame_0188.jpg
#   SKIP: Features for image already extracted.
# Processed file [189/368]
#   Name:            frame_0189.jpg
#   SKIP: Features for image already extracted.
# Processed file [190/368]
#   Name:            frame_0190.jpg
#   SKIP: Features for image already extracted.
# Processed file [191/368]
#   Name:            frame_0191.jpg
#   SKIP: Features for image already extracted.
# Processed file [192/368]
#   Name:            frame_0192.jpg
#   SKIP: Features for image already extracted.
# Processed file [193/368]
#   Name:            frame_0193.jpg
#   SKIP: Features for image already extracted.
# Processed file [194/368]
#   Name:            frame_0194.jpg
#   SKIP: Features for image already extracted.
# Processed file [195/368]
#   Name:            frame_0195.jpg
#   SKIP: Features for image already extracted.
# Processed file [196/368]
#   Name:            frame_0196.jpg
#   SKIP: Features for image already extracted.
# Processed file [197/368]
#   Name:            frame_0197.jpg
#   SKIP: Features for image already extracted.
# Processed file [198/368]
#   Name:            frame_0198.jpg
#   SKIP: Features for image already extracted.
# Processed file [199/368]
#   Name:            frame_0199.jpg
#   SKIP: Features for image already extracted.
# Processed file [200/368]
#   Name:            frame_0200.jpg
#   SKIP: Features for image already extracted.
# Processed file [201/368]
#   Name:            frame_0201.jpg
#   SKIP: Features for image already extracted.
# Processed file [202/368]
#   Name:            frame_0202.jpg
#   SKIP: Features for image already extracted.
# Processed file [203/368]
#   Name:            frame_0203.jpg
#   SKIP: Features for image already extracted.
# Processed file [204/368]
#   Name:            frame_0204.jpg
#   SKIP: Features for image already extracted.
# Processed file [205/368]
#   Name:            frame_0205.jpg
#   SKIP: Features for image already extracted.
# Processed file [206/368]
#   Name:            frame_0206.jpg
#   SKIP: Features for image already extracted.
# Processed file [207/368]
#   Name:            frame_0207.jpg
#   SKIP: Features for image already extracted.
# Processed file [208/368]
#   Name:            frame_0208.jpg
#   SKIP: Features for image already extracted.
# Processed file [209/368]
#   Name:            frame_0209.jpg
#   SKIP: Features for image already extracted.
# Processed file [210/368]
#   Name:            frame_0210.jpg
#   SKIP: Features for image already extracted.
# Processed file [211/368]
#   Name:            frame_0211.jpg
#   SKIP: Features for image already extracted.
# Processed file [212/368]
#   Name:            frame_0212.jpg
#   SKIP: Features for image already extracted.
# Processed file [213/368]
#   Name:            frame_0213.jpg
#   SKIP: Features for image already extracted.
# Processed file [214/368]
#   Name:            frame_0214.jpg
#   SKIP: Features for image already extracted.
# Processed file [215/368]
#   Name:            frame_0215.jpg
#   SKIP: Features for image already extracted.
# Processed file [216/368]
#   Name:            frame_0216.jpg
#   SKIP: Features for image already extracted.
# Processed file [217/368]
#   Name:            frame_0217.jpg
#   SKIP: Features for image already extracted.
# Processed file [218/368]
#   Name:            frame_0218.jpg
#   SKIP: Features for image already extracted.
# Processed file [219/368]
#   Name:            frame_0219.jpg
#   SKIP: Features for image already extracted.
# Processed file [220/368]
#   Name:            frame_0220.jpg
#   SKIP: Features for image already extracted.
# Processed file [221/368]
#   Name:            frame_0221.jpg
#   SKIP: Features for image already extracted.
# Processed file [222/368]
#   Name:            frame_0222.jpg
#   SKIP: Features for image already extracted.
# Processed file [223/368]
#   Name:            frame_0223.jpg
#   SKIP: Features for image already extracted.
# Processed file [224/368]
#   Name:            frame_0224.jpg
#   SKIP: Features for image already extracted.
# Processed file [225/368]
#   Name:            frame_0225.jpg
#   SKIP: Features for image already extracted.
# Processed file [226/368]
#   Name:            frame_0226.jpg
#   SKIP: Features for image already extracted.
# Processed file [227/368]
#   Name:            frame_0227.jpg
#   SKIP: Features for image already extracted.
# Processed file [228/368]
#   Name:            frame_0228.jpg
#   SKIP: Features for image already extracted.
# Processed file [229/368]
#   Name:            frame_0229.jpg
#   SKIP: Features for image already extracted.
# Processed file [230/368]
#   Name:            frame_0230.jpg
#   SKIP: Features for image already extracted.
# Processed file [231/368]
#   Name:            frame_0231.jpg
#   SKIP: Features for image already extracted.
# Processed file [232/368]
#   Name:            frame_0232.jpg
#   SKIP: Features for image already extracted.
# Processed file [233/368]
#   Name:            frame_0233.jpg
#   SKIP: Features for image already extracted.
# Processed file [234/368]
#   Name:            frame_0234.jpg
#   SKIP: Features for image already extracted.
# Processed file [235/368]
#   Name:            frame_0235.jpg
#   SKIP: Features for image already extracted.
# Processed file [236/368]
#   Name:            frame_0236.jpg
#   SKIP: Features for image already extracted.
# Processed file [237/368]
#   Name:            frame_0237.jpg
#   SKIP: Features for image already extracted.
# Processed file [238/368]
#   Name:            frame_0238.jpg
#   SKIP: Features for image already extracted.
# Processed file [239/368]
#   Name:            frame_0239.jpg
#   SKIP: Features for image already extracted.
# Processed file [240/368]
#   Name:            frame_0240.jpg
#   SKIP: Features for image already extracted.
# Processed file [241/368]
#   Name:            frame_0241.jpg
#   SKIP: Features for image already extracted.
# Processed file [242/368]
#   Name:            frame_0242.jpg
#   SKIP: Features for image already extracted.
# Processed file [243/368]
#   Name:            frame_0243.jpg
#   SKIP: Features for image already extracted.
# Processed file [244/368]
#   Name:            frame_0244.jpg
#   SKIP: Features for image already extracted.
# Processed file [245/368]
#   Name:            frame_0245.jpg
#   SKIP: Features for image already extracted.
# Processed file [246/368]
#   Name:            frame_0246.jpg
#   SKIP: Features for image already extracted.
# Processed file [247/368]
#   Name:            frame_0247.jpg
#   SKIP: Features for image already extracted.
# Processed file [248/368]
#   Name:            frame_0248.jpg
#   SKIP: Features for image already extracted.
# Processed file [249/368]
#   Name:            frame_0249.jpg
#   SKIP: Features for image already extracted.
# Processed file [250/368]
#   Name:            frame_0250.jpg
#   SKIP: Features for image already extracted.
# Processed file [251/368]
#   Name:            frame_0251.jpg
#   SKIP: Features for image already extracted.
# Processed file [252/368]
#   Name:            frame_0252.jpg
#   SKIP: Features for image already extracted.
# Processed file [253/368]
#   Name:            frame_0253.jpg
#   SKIP: Features for image already extracted.
# Processed file [254/368]
#   Name:            frame_0254.jpg
#   SKIP: Features for image already extracted.
# Processed file [255/368]
#   Name:            frame_0255.jpg
#   SKIP: Features for image already extracted.
# Processed file [256/368]
#   Name:            frame_0256.jpg
#   SKIP: Features for image already extracted.
# Processed file [257/368]
#   Name:            frame_0257.jpg
#   SKIP: Features for image already extracted.
# Processed file [258/368]
#   Name:            frame_0258.jpg
#   SKIP: Features for image already extracted.
# Processed file [259/368]
#   Name:            frame_0259.jpg
#   SKIP: Features for image already extracted.
# Processed file [260/368]
#   Name:            frame_0260.jpg
#   SKIP: Features for image already extracted.
# Processed file [261/368]
#   Name:            frame_0261.jpg
#   SKIP: Features for image already extracted.
# Processed file [262/368]
#   Name:            frame_0262.jpg
#   SKIP: Features for image already extracted.
# Processed file [263/368]
#   Name:            frame_0263.jpg
#   SKIP: Features for image already extracted.
# Processed file [264/368]
#   Name:            frame_0264.jpg
#   SKIP: Features for image already extracted.
# Processed file [265/368]
#   Name:            frame_0265.jpg
#   SKIP: Features for image already extracted.
# Processed file [266/368]
#   Name:            frame_0266.jpg
#   SKIP: Features for image already extracted.
# Processed file [267/368]
#   Name:            frame_0267.jpg
#   SKIP: Features for image already extracted.
# Processed file [268/368]
#   Name:            frame_0268.jpg
#   SKIP: Features for image already extracted.
# Processed file [269/368]
#   Name:            frame_0269.jpg
#   SKIP: Features for image already extracted.
# Processed file [270/368]
#   Name:            frame_0270.jpg
#   SKIP: Features for image already extracted.
# Processed file [271/368]
#   Name:            frame_0271.jpg
#   SKIP: Features for image already extracted.
# Processed file [272/368]
#   Name:            frame_0272.jpg
#   SKIP: Features for image already extracted.
# Processed file [273/368]
#   Name:            frame_0273.jpg
#   SKIP: Features for image already extracted.
# Processed file [274/368]
#   Name:            frame_0274.jpg
#   SKIP: Features for image already extracted.
# Processed file [275/368]
#   Name:            frame_0275.jpg
#   SKIP: Features for image already extracted.
# Processed file [276/368]
#   Name:            frame_0276.jpg
#   SKIP: Features for image already extracted.
# Processed file [277/368]
#   Name:            frame_0277.jpg
#   SKIP: Features for image already extracted.
# Processed file [278/368]
#   Name:            frame_0278.jpg
#   SKIP: Features for image already extracted.
# Processed file [279/368]
#   Name:            frame_0279.jpg
#   SKIP: Features for image already extracted.
# Processed file [280/368]
#   Name:            frame_0280.jpg
#   SKIP: Features for image already extracted.
# Processed file [281/368]
#   Name:            frame_0281.jpg
#   SKIP: Features for image already extracted.
# Processed file [282/368]
#   Name:            frame_0282.jpg
#   SKIP: Features for image already extracted.
# Processed file [283/368]
#   Name:            frame_0283.jpg
#   SKIP: Features for image already extracted.
# Processed file [284/368]
#   Name:            frame_0284.jpg
#   SKIP: Features for image already extracted.
# Processed file [285/368]
#   Name:            frame_0285.jpg
#   SKIP: Features for image already extracted.
# Processed file [286/368]
#   Name:            frame_0286.jpg
#   SKIP: Features for image already extracted.
# Processed file [287/368]
#   Name:            frame_0287.jpg
#   SKIP: Features for image already extracted.
# Processed file [288/368]
#   Name:            frame_0288.jpg
#   SKIP: Features for image already extracted.
# Processed file [289/368]
#   Name:            frame_0289.jpg
#   SKIP: Features for image already extracted.
# Processed file [290/368]
#   Name:            frame_0290.jpg
#   SKIP: Features for image already extracted.
# Processed file [291/368]
#   Name:            frame_0291.jpg
#   SKIP: Features for image already extracted.
# Processed file [292/368]
#   Name:            frame_0292.jpg
#   SKIP: Features for image already extracted.
# Processed file [293/368]
#   Name:            frame_0293.jpg
#   SKIP: Features for image already extracted.
# Processed file [294/368]
#   Name:            frame_0294.jpg
#   SKIP: Features for image already extracted.
# Processed file [295/368]
#   Name:            frame_0295.jpg
#   SKIP: Features for image already extracted.
# Processed file [296/368]
#   Name:            frame_0296.jpg
#   SKIP: Features for image already extracted.
# Processed file [297/368]
#   Name:            frame_0297.jpg
#   SKIP: Features for image already extracted.
# Processed file [298/368]
#   Name:            frame_0298.jpg
#   SKIP: Features for image already extracted.
# Processed file [299/368]
#   Name:            frame_0299.jpg
#   SKIP: Features for image already extracted.
# Processed file [300/368]
#   Name:            frame_0300.jpg
#   SKIP: Features for image already extracted.
# Processed file [301/368]
#   Name:            frame_0301.jpg
#   SKIP: Features for image already extracted.
# Processed file [302/368]
#   Name:            frame_0302.jpg
#   SKIP: Features for image already extracted.
# Processed file [303/368]
#   Name:            frame_0303.jpg
#   SKIP: Features for image already extracted.
# Processed file [304/368]
#   Name:            frame_0304.jpg
#   SKIP: Features for image already extracted.
# Processed file [305/368]
#   Name:            frame_0305.jpg
#   SKIP: Features for image already extracted.
# Processed file [306/368]
#   Name:            frame_0306.jpg
#   SKIP: Features for image already extracted.
# Processed file [307/368]
#   Name:            frame_0307.jpg
#   SKIP: Features for image already extracted.
# Processed file [308/368]
#   Name:            frame_0308.jpg
#   SKIP: Features for image already extracted.
# Processed file [309/368]
#   Name:            frame_0309.jpg
#   SKIP: Features for image already extracted.
# Processed file [310/368]
#   Name:            frame_0310.jpg
#   SKIP: Features for image already extracted.
# Processed file [311/368]
#   Name:            frame_0311.jpg
#   SKIP: Features for image already extracted.
# Processed file [312/368]
#   Name:            frame_0312.jpg
#   SKIP: Features for image already extracted.
# Processed file [313/368]
#   Name:            frame_0313.jpg
#   SKIP: Features for image already extracted.
# Processed file [314/368]
#   Name:            frame_0314.jpg
#   SKIP: Features for image already extracted.
# Processed file [315/368]
#   Name:            frame_0315.jpg
#   SKIP: Features for image already extracted.
# Processed file [316/368]
#   Name:            frame_0316.jpg
#   SKIP: Features for image already extracted.
# Processed file [317/368]
#   Name:            frame_0317.jpg
#   SKIP: Features for image already extracted.
# Processed file [318/368]
#   Name:            frame_0318.jpg
#   SKIP: Features for image already extracted.
# Processed file [319/368]
#   Name:            frame_0319.jpg
#   SKIP: Features for image already extracted.
# Processed file [320/368]
#   Name:            frame_0320.jpg
#   SKIP: Features for image already extracted.
# Processed file [321/368]
#   Name:            frame_0321.jpg
#   SKIP: Features for image already extracted.
# Processed file [322/368]
#   Name:            frame_0322.jpg
#   SKIP: Features for image already extracted.
# Processed file [323/368]
#   Name:            frame_0323.jpg
#   SKIP: Features for image already extracted.
# Processed file [324/368]
#   Name:            frame_0324.jpg
#   SKIP: Features for image already extracted.
# Processed file [325/368]
#   Name:            frame_0325.jpg
#   SKIP: Features for image already extracted.
# Processed file [326/368]
#   Name:            frame_0326.jpg
#   SKIP: Features for image already extracted.
# Processed file [327/368]
#   Name:            frame_0327.jpg
#   SKIP: Features for image already extracted.
# Processed file [328/368]
#   Name:            frame_0328.jpg
#   SKIP: Features for image already extracted.
# Processed file [329/368]
#   Name:            frame_0329.jpg
#   SKIP: Features for image already extracted.
# Processed file [330/368]
#   Name:            frame_0330.jpg
#   SKIP: Features for image already extracted.
# Processed file [331/368]
#   Name:            frame_0331.jpg
#   SKIP: Features for image already extracted.
# Processed file [332/368]
#   Name:            frame_0332.jpg
#   SKIP: Features for image already extracted.
# Processed file [333/368]
#   Name:            frame_0333.jpg
#   SKIP: Features for image already extracted.
# Processed file [334/368]
#   Name:            frame_0334.jpg
#   SKIP: Features for image already extracted.
# Processed file [335/368]
#   Name:            frame_0335.jpg
#   SKIP: Features for image already extracted.
# Processed file [336/368]
#   Name:            frame_0336.jpg
#   SKIP: Features for image already extracted.
# Processed file [337/368]
#   Name:            frame_0337.jpg
#   SKIP: Features for image already extracted.
# Processed file [338/368]
#   Name:            frame_0338.jpg
#   SKIP: Features for image already extracted.
# Processed file [339/368]
#   Name:            frame_0339.jpg
#   SKIP: Features for image already extracted.
# Processed file [340/368]
#   Name:            frame_0340.jpg
#   SKIP: Features for image already extracted.
# Processed file [341/368]
#   Name:            frame_0341.jpg
#   SKIP: Features for image already extracted.
# Processed file [342/368]
#   Name:            frame_0342.jpg
#   SKIP: Features for image already extracted.
# Processed file [343/368]
#   Name:            frame_0343.jpg
#   SKIP: Features for image already extracted.
# Processed file [344/368]
#   Name:            frame_0344.jpg
#   SKIP: Features for image already extracted.
# Processed file [345/368]
#   Name:            frame_0345.jpg
#   SKIP: Features for image already extracted.
# Processed file [346/368]
#   Name:            frame_0346.jpg
#   SKIP: Features for image already extracted.
# Processed file [347/368]
#   Name:            frame_0347.jpg
#   SKIP: Features for image already extracted.
# Processed file [348/368]
#   Name:            frame_0348.jpg
#   SKIP: Features for image already extracted.
# Processed file [349/368]
#   Name:            frame_0349.jpg
#   SKIP: Features for image already extracted.
# Processed file [350/368]
#   Name:            frame_0350.jpg
#   SKIP: Features for image already extracted.
# Processed file [351/368]
#   Name:            frame_0351.jpg
#   SKIP: Features for image already extracted.
# Processed file [352/368]
#   Name:            frame_0352.jpg
#   SKIP: Features for image already extracted.
# Processed file [353/368]
#   Name:            frame_0353.jpg
#   SKIP: Features for image already extracted.
# Processed file [354/368]
#   Name:            frame_0354.jpg
#   SKIP: Features for image already extracted.
# Processed file [355/368]
#   Name:            frame_0355.jpg
#   SKIP: Features for image already extracted.
# Processed file [356/368]
#   Name:            frame_0356.jpg
#   SKIP: Features for image already extracted.
# Processed file [357/368]
#   Name:            frame_0357.jpg
#   SKIP: Features for image already extracted.
# Processed file [358/368]
#   Name:            frame_0358.jpg
#   SKIP: Features for image already extracted.
# Processed file [359/368]
#   Name:            frame_0359.jpg
#   SKIP: Features for image already extracted.
# Processed file [360/368]
#   Name:            frame_0360.jpg
#   SKIP: Features for image already extracted.
# Processed file [361/368]
#   Name:            frame_0361.jpg
#   SKIP: Features for image already extracted.
# Processed file [362/368]
#   Name:            frame_0362.jpg
#   SKIP: Features for image already extracted.
# Processed file [363/368]
#   Name:            frame_0363.jpg
#   SKIP: Features for image already extracted.
# Processed file [364/368]
#   Name:            frame_0364.jpg
#   SKIP: Features for image already extracted.
# Processed file [365/368]
#   Name:            frame_0365.jpg
#   SKIP: Features for image already extracted.
# Processed file [366/368]
#   Name:            frame_0366.jpg
#   SKIP: Features for image already extracted.
# Processed file [367/368]
#   Name:            frame_0367.jpg
#   SKIP: Features for image already extracted.
# Processed file [368/368]
#   Name:            frame_0368.jpg
#   SKIP: Features for image already extracted.
# Elapsed time: 0.003 [minutes]
#  Feature extraction with CPU completed

# %%
# # Matching the features
# database_path = f"{workspace_dir}/database/database.db"

# !colmap exhaustive_matcher \
#    --database_path "{database_path}" \
#    --SiftMatching.use_gpu=false  # CPU

# print("Feature matching with CPU completed")


# if os.path.exists(database_path):
#     new_size = os.path.getsize(database_path) / (1024*1024)
#     print(f" Database size after matching: {new_size:.1f} MB")

# %% [markdown]
# # Sequential Matcheing for 5 sequences of frames

# %%
# Sequential Matcher
# !colmap sequential_matcher \
   --database_path "{database_path}" \
   --SiftMatching.use_gpu=false \
   --SequentialMatching.overlap=5  # 5 sequential frames
# Out:
# ==============================================================================
# Sequential feature matching
# ==============================================================================
#
# Matching image [1/368] in 0.003s
# Matching image [2/368] in 0.001s
# Matching image [3/368] in 0.001s
# Matching image [4/368] in 0.001s
# Matching image [5/368] in 0.001s
# Matching image [6/368] in 0.001s
# Matching image [7/368] in 0.001s
# Matching image [8/368] in 0.001s
# Matching image [9/368] in 0.001s
# Matching image [10/368] in 0.001s
# Matching image [11/368] in 0.001s
# Matching image [12/368] in 0.001s
# Matching image [13/368] in 0.001s
# Matching image [14/368] in 0.001s
# Matching image [15/368] in 0.001s
# Matching image [16/368] in 0.001s
# Matching image [17/368] in 0.001s
# Matching image [18/368] in 0.001s
# Matching image [19/368] in 0.001s
# Matching image [20/368] in 0.001s
# Matching image [21/368] in 0.001s
# Matching image [22/368] in 0.001s
# Matching image [23/368] in 0.001s
# Matching image [24/368] in 0.001s
# Matching image [25/368] in 0.001s
# Matching image [26/368] in 0.000s
# Matching image [27/368] in 0.000s
# Matching image [28/368] in 0.001s
# Matching image [29/368] in 0.001s
# Matching image [30/368] in 0.000s
# Matching image [31/368] in 0.001s
# Matching image [32/368] in 0.000s
# Matching image [33/368] in 0.000s
# Matching image [34/368] in 0.000s
# Matching image [35/368] in 0.000s
# Matching image [36/368] in 0.000s
# Matching image [37/368] in 0.000s
# Matching image [38/368] in 0.001s
# Matching image [39/368] in 0.000s
# Matching image [40/368] in 0.000s
# Matching image [41/368] in 0.000s
# Matching image [42/368] in 0.000s
# Matching image [43/368] in 0.001s
# Matching image [44/368] in 0.001s
# Matching image [45/368] in 0.000s
# Matching image [46/368] in 0.001s
# Matching image [47/368] in 0.001s
# Matching image [48/368] in 0.000s
# Matching image [49/368] in 0.000s
# Matching image [50/368] in 0.000s
# Matching image [51/368] in 0.001s
# Matching image [52/368] in 0.000s
# Matching image [53/368] in 0.001s
# Matching image [54/368] in 0.000s
# Matching image [55/368] in 0.000s
# Matching image [56/368] in 0.000s
# Matching image [57/368] in 0.000s
# Matching image [58/368] in 0.000s
# Matching image [59/368] in 0.000s
# Matching image [60/368] in 0.000s
# Matching image [61/368] in 0.000s
# Matching image [62/368] in 0.000s
# Matching image [63/368] in 0.000s
# Matching image [64/368] in 0.001s
# Matching image [65/368] in 0.001s
# Matching image [66/368] in 0.000s
# Matching image [67/368] in 0.001s
# Matching image [68/368] in 0.000s
# Matching image [69/368] in 0.001s
# Matching image [70/368] in 0.000s
# Matching image [71/368] in 0.000s
# Matching image [72/368] in 0.000s
# Matching image [73/368] in 0.000s
# Matching image [74/368] in 0.000s
# Matching image [75/368] in 0.000s
# Matching image [76/368] in 0.000s
# Matching image [77/368] in 0.000s
# Matching image [78/368] in 0.000s
# Matching image [79/368] in 0.000s
# Matching image [80/368] in 0.000s
# Matching image [81/368] in 0.000s
# Matching image [82/368] in 0.000s
# Matching image [83/368] in 0.000s
# Matching image [84/368] in 0.000s
# Matching image [85/368] in 0.000s
# Matching image [86/368] in 0.000s
# Matching image [87/368] in 0.000s
# Matching image [88/368] in 0.000s
# Matching image [89/368] in 0.000s
# Matching image [90/368] in 0.000s
# Matching image [91/368] in 0.000s
# Matching image [92/368] in 0.000s
# Matching image [93/368] in 0.000s
# Matching image [94/368] in 0.000s
# Matching image [95/368] in 0.000s
# Matching image [96/368] in 0.000s
# Matching image [97/368] in 0.000s
# Matching image [98/368] in 0.000s
# Matching image [99/368] in 0.000s
# Matching image [100/368] in 0.000s
# Matching image [101/368] in 0.000s
# Matching image [102/368] in 0.000s
# Matching image [103/368] in 0.000s
# Matching image [104/368] in 0.000s
# Matching image [105/368] in 0.000s
# Matching image [106/368] in 0.000s
# Matching image [107/368] in 0.000s
# Matching image [108/368] in 0.000s
# Matching image [109/368] in 0.000s
# Matching image [110/368] in 0.000s
# Matching image [111/368] in 0.000s
# Matching image [112/368] in 0.000s
# Matching image [113/368] in 0.000s
# Matching image [114/368] in 0.000s
# Matching image [115/368] in 0.000s
# Matching image [116/368] in 0.000s
# Matching image [117/368] in 0.000s
# Matching image [118/368] in 0.000s
# Matching image [119/368] in 0.000s
# Matching image [120/368] in 0.000s
# Matching image [121/368] in 0.000s
# Matching image [122/368] in 0.000s
# Matching image [123/368] in 0.000s
# Matching image [124/368] in 0.000s
# Matching image [125/368] in 0.000s
# Matching image [126/368] in 0.000s
# Matching image [127/368] in 0.000s
# Matching image [128/368] in 0.000s
# Matching image [129/368] in 0.000s
# Matching image [130/368] in 0.000s
# Matching image [131/368] in 0.000s
# Matching image [132/368] in 0.000s
# Matching image [133/368] in 0.000s
# Matching image [134/368] in 0.000s
# Matching image [135/368] in 0.000s
# Matching image [136/368] in 0.001s
# Matching image [137/368] in 0.000s
# Matching image [138/368] in 0.000s
# Matching image [139/368] in 0.000s
# Matching image [140/368] in 0.001s
# Matching image [141/368] in 0.000s
# Matching image [142/368] in 0.001s
# Matching image [143/368] in 0.000s
# Matching image [144/368] in 0.000s
# Matching image [145/368] in 0.001s
# Matching image [146/368] in 0.000s
# Matching image [147/368] in 0.000s
# Matching image [148/368] in 0.000s
# Matching image [149/368] in 0.000s
# Matching image [150/368] in 0.001s
# Matching image [151/368] in 0.001s
# Matching image [152/368] in 0.001s
# Matching image [153/368] in 0.001s
# Matching image [154/368] in 0.001s
# Matching image [155/368] in 0.001s
# Matching image [156/368] in 0.001s
# Matching image [157/368] in 0.001s
# Matching image [158/368] in 0.001s
# Matching image [159/368] in 0.001s
# Matching image [160/368] in 0.001s
# Matching image [161/368] in 0.001s
# Matching image [162/368] in 0.000s
# Matching image [163/368] in 0.001s
# Matching image [164/368] in 0.000s
# Matching image [165/368] in 0.001s
# Matching image [166/368] in 0.001s
# Matching image [167/368] in 0.001s
# Matching image [168/368] in 0.001s
# Matching image [169/368] in 0.001s
# Matching image [170/368] in 0.001s
# Matching image [171/368] in 0.001s
# Matching image [172/368] in 0.001s
# Matching image [173/368] in 0.001s
# Matching image [174/368] in 0.001s
# Matching image [175/368] in 0.001s
# Matching image [176/368] in 0.000s
# Matching image [177/368] in 0.001s
# Matching image [178/368] in 0.000s
# Matching image [179/368] in 0.000s
# Matching image [180/368] in 0.000s
# Matching image [181/368] in 0.001s
# Matching image [182/368] in 0.000s
# Matching image [183/368] in 0.001s
# Matching image [184/368] in 0.001s
# Matching image [185/368] in 0.001s
# Matching image [186/368] in 0.001s
# Matching image [187/368] in 0.001s
# Matching image [188/368] in 0.001s
# Matching image [189/368] in 0.001s
# Matching image [190/368] in 0.000s
# Matching image [191/368] in 0.001s
# Matching image [192/368] in 0.001s
# Matching image [193/368] in 0.000s
# Matching image [194/368] in 0.001s
# Matching image [195/368] in 0.000s
# Matching image [196/368] in 0.001s
# Matching image [197/368] in 0.000s
# Matching image [198/368] in 0.001s
# Matching image [199/368] in 0.000s
# Matching image [200/368] in 0.000s
# Matching image [201/368] in 0.000s
# Matching image [202/368] in 0.000s
# Matching image [203/368] in 0.000s
# Matching image [204/368] in 0.000s
# Matching image [205/368] in 0.000s
# Matching image [206/368] in 0.000s
# Matching image [207/368] in 0.000s
# Matching image [208/368] in 0.000s
# Matching image [209/368] in 0.000s
# Matching image [210/368] in 0.000s
# Matching image [211/368] in 0.000s
# Matching image [212/368] in 0.001s
# Matching image [213/368] in 0.000s
# Matching image [214/368] in 0.000s
# Matching image [215/368] in 0.000s
# Matching image [216/368] in 0.000s
# Matching image [217/368] in 0.000s
# Matching image [218/368] in 0.000s
# Matching image [219/368] in 0.000s
# Matching image [220/368] in 0.002s
# Matching image [221/368] in 0.000s
# Matching image [222/368] in 0.001s
# Matching image [223/368] in 0.000s
# Matching image [224/368] in 0.000s
# Matching image [225/368] in 0.000s
# Matching image [226/368] in 0.000s
# Matching image [227/368] in 0.000s
# Matching image [228/368] in 0.000s
# Matching image [229/368] in 0.000s
# Matching image [230/368] in 0.000s
# Matching image [231/368] in 0.000s
# Matching image [232/368] in 0.001s
# Matching image [233/368] in 0.000s
# Matching image [234/368] in 0.000s
# Matching image [235/368] in 0.000s
# Matching image [236/368] in 0.000s
# Matching image [237/368] in 0.001s
# Matching image [238/368] in 0.000s
# Matching image [239/368] in 0.000s
# Matching image [240/368] in 0.001s
# Matching image [241/368] in 0.000s
# Matching image [242/368] in 0.000s
# Matching image [243/368] in 0.000s
# Matching image [244/368] in 0.000s
# Matching image [245/368] in 0.000s
# Matching image [246/368] in 0.000s
# Matching image [247/368] in 0.000s
# Matching image [248/368] in 0.000s
# Matching image [249/368] in 0.000s
# Matching image [250/368] in 0.000s
# Matching image [251/368] in 0.000s
# Matching image [252/368] in 0.000s
# Matching image [253/368] in 0.000s
# Matching image [254/368] in 0.000s
# Matching image [255/368] in 0.000s
# Matching image [256/368] in 0.001s
# Matching image [257/368] in 0.000s
# Matching image [258/368] in 0.001s
# Matching image [259/368] in 0.000s
# Matching image [260/368] in 0.000s
# Matching image [261/368] in 0.000s
# Matching image [262/368] in 0.001s
# Matching image [263/368] in 0.001s
# Matching image [264/368] in 0.000s
# Matching image [265/368] in 0.000s
# Matching image [266/368] in 0.001s
# Matching image [267/368] in 0.000s
# Matching image [268/368] in 0.000s
# Matching image [269/368] in 0.000s
# Matching image [270/368] in 0.000s
# Matching image [271/368] in 0.000s
# Matching image [272/368] in 0.000s
# Matching image [273/368] in 0.000s
# Matching image [274/368] in 0.000s
# Matching image [275/368] in 0.001s
# Matching image [276/368] in 0.000s
# Matching image [277/368] in 0.000s
# Matching image [278/368] in 0.000s
# Matching image [279/368] in 0.000s
# Matching image [280/368] in 0.000s
# Matching image [281/368] in 0.000s
# Matching image [282/368] in 0.000s
# Matching image [283/368] in 0.000s
# Matching image [284/368] in 0.001s
# Matching image [285/368] in 0.001s
# Matching image [286/368] in 0.000s
# Matching image [287/368] in 0.000s
# Matching image [288/368] in 0.000s
# Matching image [289/368] in 0.001s
# Matching image [290/368] in 0.001s
# Matching image [291/368] in 0.000s
# Matching image [292/368] in 0.001s
# Matching image [293/368] in 0.001s
# Matching image [294/368] in 0.000s
# Matching image [295/368] in 0.000s
# Matching image [296/368] in 0.000s
# Matching image [297/368] in 0.000s
# Matching image [298/368] in 0.000s
# Matching image [299/368] in 0.000s
# Matching image [300/368] in 0.000s
# Matching image [301/368] in 0.000s
# Matching image [302/368] in 0.000s
# Matching image [303/368] in 0.000s
# Matching image [304/368] in 0.000s
# Matching image [305/368] in 0.000s
# Matching image [306/368] in 0.000s
# Matching image [307/368] in 0.000s
# Matching image [308/368] in 0.000s
# Matching image [309/368] in 0.001s
# Matching image [310/368] in 0.001s
# Matching image [311/368] in 0.000s
# Matching image [312/368] in 0.001s
# Matching image [313/368] in 0.000s
# Matching image [314/368] in 0.000s
# Matching image [315/368] in 0.000s
# Matching image [316/368] in 0.000s
# Matching image [317/368] in 0.000s
# Matching image [318/368] in 0.000s
# Matching image [319/368] in 0.000s
# Matching image [320/368] in 0.000s
# Matching image [321/368] in 0.000s
# Matching image [322/368] in 0.000s
# Matching image [323/368] in 0.000s
# Matching image [324/368] in 0.000s
# Matching image [325/368] in 0.000s
# Matching image [326/368] in 0.000s
# Matching image [327/368] in 0.001s
# Matching image [328/368] in 0.001s
# Matching image [329/368] in 0.000s
# Matching image [330/368] in 0.000s
# Matching image [331/368] in 0.001s
# Matching image [332/368] in 0.001s
# Matching image [333/368] in 0.001s
# Matching image [334/368] in 0.000s
# Matching image [335/368] in 0.000s
# Matching image [336/368] in 0.000s
# Matching image [337/368] in 0.000s
# Matching image [338/368] in 0.000s
# Matching image [339/368] in 0.000s
# Matching image [340/368] in 0.000s
# Matching image [341/368] in 0.000s
# Matching image [342/368] in 0.000s
# Matching image [343/368] in 0.000s
# Matching image [344/368] in 0.001s
# Matching image [345/368] in 0.000s
# Matching image [346/368] in 0.000s
# Matching image [347/368] in 0.000s
# Matching image [348/368] in 0.001s
# Matching image [349/368] in 0.000s
# Matching image [350/368] in 0.000s
# Matching image [351/368] in 0.000s
# Matching image [352/368] in 0.000s
# Matching image [353/368] in 0.000s
# Matching image [354/368] in 0.000s
# Matching image [355/368] in 0.000s
# Matching image [356/368] in 0.000s
# Matching image [357/368] in 0.000s
# Matching image [358/368] in 0.000s
# Matching image [359/368] in 0.000s
# Matching image [360/368] in 0.000s
# Matching image [361/368] in 0.001s
# Matching image [362/368] in 0.000s
# Matching image [363/368] in 0.000s
# Matching image [364/368] in 0.001s
# Matching image [365/368] in 0.001s
# Matching image [366/368] in 0.000s
# Matching image [367/368] in 0.000s
# Matching image [368/368] in 0.000s
# Elapsed time: 0.003 [minutes]

# %%
import sqlite3
import pandas as pd

# conn = sqlite3.connect(database_path)
# conn.execute("DROP TABLE IF EXISTS matches;")
# conn.execute("DROP TABLE IF EXISTS two_view_geometries;")
# conn.commit()
# conn.close()
# print(" Removed tables")

conn = sqlite3.connect(database_path)
matches_count = pd.read_sql_query("SELECT COUNT(*) FROM matches;", conn).iloc[0,0]
print(f" # matches: {matches_count}")
conn.close()
# Out:
#  # matches: 2174

# %% [markdown]
# # **Triangulation for extracting 3D points cloud with estimated Camera positions**

# %%
workspace_dir = "/content/drive/MyDrive/3DCV/HW2/COLMAP"
database_path = f"{workspace_dir}/database/database.db"
frames_dir = f"{workspace_dir}/frames"
sparse_dir = f"{workspace_dir}/output/sparse"


# !colmap mapper \
    --database_path "{database_path}" \
    --image_path "{frames_dir}" \
    --output_path "{sparse_dir}"
# Out:
# Streaming output truncated to the last 5000 lines.
#
#   => Continued observations: 847
#   => Added observations: 468
#
# Bundle adjustment report
# ------------------------
#     Residuals : 15140
#    Parameters : 1847
#    Iterations : 11
#          Time : 0.292666 [s]
#  Initial cost : 0.50129 [px]
#    Final cost : 0.492728 [px]
#   Termination : Convergence
#
#   => Merged observations: 77
#   => Completed observations: 216
#   => Filtered observations: 38
#   => Changed observations: 0.038138
#
# Bundle adjustment report
# ------------------------
#     Residuals : 15452
#    Parameters : 1862
#    Iterations : 4
#          Time : 0.12558 [s]
#  Initial cost : 0.589428 [px]
#    Final cost : 0.583637 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 5
#   => Filtered observations: 3
#   => Changed observations: 0.000927
#
# ==============================================================================
# Registering image #26 (279)
# ==============================================================================
#
#   => Image sees 836 / 3353 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1676
#    Parameters : 6
#    Iterations : 8
#          Time : 0.0206571 [s]
#  Initial cost : 0.496247 [px]
#    Final cost : 0.486015 [px]
#   Termination : Convergence
#
#   => Continued observations: 822
#   => Added observations: 476
#
# Bundle adjustment report
# ------------------------
#     Residuals : 15358
#    Parameters : 1961
#    Iterations : 9
#          Time : 0.267924 [s]
#  Initial cost : 0.497972 [px]
#    Final cost : 0.487182 [px]
#   Termination : Convergence
#
#   => Merged observations: 104
#   => Completed observations: 197
#   => Filtered observations: 22
#   => Changed observations: 0.037681
#
# Bundle adjustment report
# ------------------------
#     Residuals : 15580
#    Parameters : 1937
#    Iterations : 3
#          Time : 0.08971 [s]
#  Initial cost : 0.599142 [px]
#    Final cost : 0.594247 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 1
#   => Filtered observations: 1
#   => Changed observations: 0.000230
#
# ==============================================================================
# Registering image #25 (280)
# ==============================================================================
#
#   => Image sees 920 / 3560 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1864
#    Parameters : 6
#    Iterations : 8
#          Time : 0.0233731 [s]
#  Initial cost : 0.587107 [px]
#    Final cost : 0.490465 [px]
#   Termination : Convergence
#
#   => Continued observations: 914
#   => Added observations: 466
#
# Bundle adjustment report
# ------------------------
#     Residuals : 16282
#    Parameters : 2090
#    Iterations : 26
#          Time : 0.738263 [s]
#  Initial cost : 0.502871 [px]
#    Final cost : 0.492285 [px]
#   Termination : No convergence
#
#   => Merged observations: 203
#   => Completed observations: 216
#   => Filtered observations: 40
#   => Changed observations: 0.050401
#
# Bundle adjustment report
# ------------------------
#     Residuals : 16536
#    Parameters : 2060
#    Iterations : 4
#          Time : 0.117021 [s]
#  Initial cost : 0.60226 [px]
#    Final cost : 0.594765 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 13
#   => Filtered observations: 2
#   => Changed observations: 0.001624
#
# ==============================================================================
# Registering image #24 (281)
# ==============================================================================
#
#   => Image sees 925 / 4047 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1864
#    Parameters : 6
#    Iterations : 8
#          Time : 0.021291 [s]
#  Initial cost : 0.543965 [px]
#    Final cost : 0.474097 [px]
#   Termination : Convergence
#
#   => Continued observations: 916
#   => Added observations: 379
#
# Bundle adjustment report
# ------------------------
#     Residuals : 16762
#    Parameters : 2129
#    Iterations : 23
#          Time : 0.70354 [s]
#  Initial cost : 0.504711 [px]
#    Final cost : 0.494547 [px]
#   Termination : Convergence
#
#   => Merged observations: 174
#   => Completed observations: 216
#   => Filtered observations: 46
#   => Changed observations: 0.046766
#
# Bundle adjustment report
# ------------------------
#     Residuals : 17014
#    Parameters : 2096
#    Iterations : 4
#          Time : 0.127119 [s]
#  Initial cost : 0.600087 [px]
#    Final cost : 0.593759 [px]
#   Termination : Convergence
#
#   => Merged observations: 26
#   => Completed observations: 13
#   => Filtered observations: 1
#   => Changed observations: 0.004232
#
# ==============================================================================
# Registering image #23 (282)
# ==============================================================================
#
#   => Image sees 905 / 4072 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1840
#    Parameters : 6
#    Iterations : 9
#          Time : 0.026546 [s]
#  Initial cost : 0.67667 [px]
#    Final cost : 0.47823 [px]
#   Termination : Convergence
#
#   => Continued observations: 898
#   => Added observations: 310
#
# Bundle adjustment report
# ------------------------
#     Residuals : 16992
#    Parameters : 1919
#    Iterations : 26
#          Time : 0.543046 [s]
#  Initial cost : 0.513783 [px]
#    Final cost : 0.502903 [px]
#   Termination : No convergence
#
#   => Merged observations: 282
#   => Completed observations: 176
#   => Filtered observations: 52
#   => Changed observations: 0.053650
#
# Bundle adjustment report
# ------------------------
#     Residuals : 17168
#    Parameters : 1862
#    Iterations : 4
#          Time : 0.077601 [s]
#  Initial cost : 0.610233 [px]
#    Final cost : 0.602051 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 8
#   => Filtered observations: 0
#   => Changed observations: 0.000834
#
# ==============================================================================
# Registering image #22 (283)
# ==============================================================================
#
#   => Image sees 942 / 4441 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1894
#    Parameters : 6
#    Iterations : 9
#          Time : 0.0161519 [s]
#  Initial cost : 0.647108 [px]
#    Final cost : 0.471875 [px]
#   Termination : Convergence
#
#   => Continued observations: 929
#   => Added observations: 307
#
# Bundle adjustment report
# ------------------------
#     Residuals : 17830
#    Parameters : 1967
#    Iterations : 26
#          Time : 0.518719 [s]
#  Initial cost : 0.500995 [px]
#    Final cost : 0.49302 [px]
#   Termination : No convergence
#
#   => Merged observations: 139
#   => Completed observations: 216
#   => Filtered observations: 37
#   => Changed observations: 0.039644
#
# Bundle adjustment report
# ------------------------
#     Residuals : 18112
#    Parameters : 1943
#    Iterations : 4
#          Time : 0.0824499 [s]
#  Initial cost : 0.599983 [px]
#    Final cost : 0.595378 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 6
#   => Filtered observations: 1
#   => Changed observations: 0.000699
#
# ==============================================================================
# Registering image #20 (284)
# ==============================================================================
#
#   => Image sees 866 / 4406 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1728
#    Parameters : 6
#    Iterations : 9
#          Time : 0.0148849 [s]
#  Initial cost : 0.621304 [px]
#    Final cost : 0.47409 [px]
#   Termination : Convergence
#
#   => Continued observations: 856
#   => Added observations: 304
#
# Bundle adjustment report
# ------------------------
#     Residuals : 17332
#    Parameters : 1661
#    Iterations : 26
#          Time : 0.491836 [s]
#  Initial cost : 0.51342 [px]
#    Final cost : 0.500443 [px]
#   Termination : No convergence
#
#   => Merged observations: 75
#   => Completed observations: 206
#   => Filtered observations: 52
#   => Changed observations: 0.034143
#
# Bundle adjustment report
# ------------------------
#     Residuals : 17624
#    Parameters : 1625
#    Iterations : 4
#          Time : 0.0851221 [s]
#  Initial cost : 0.607024 [px]
#    Final cost : 0.601057 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 16
#   => Filtered observations: 1
#   => Changed observations: 0.001717
#
# ==============================================================================
# Registering image #21 (285)
# ==============================================================================
#
#   => Image sees 977 / 4409 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1986
#    Parameters : 6
#    Iterations : 8
#          Time : 0.0151269 [s]
#  Initial cost : 0.478201 [px]
#    Final cost : 0.467447 [px]
#   Termination : Convergence
#
#   => Continued observations: 968
#   => Added observations: 354
#
# Bundle adjustment report
# ------------------------
#     Residuals : 18552
#    Parameters : 1991
#    Iterations : 26
#          Time : 0.51031 [s]
#  Initial cost : 0.506872 [px]
#    Final cost : 0.495385 [px]
#   Termination : No convergence
#
#   => Merged observations: 187
#   => Completed observations: 246
#   => Filtered observations: 60
#   => Changed observations: 0.047850
#
# Bundle adjustment report
# ------------------------
#     Residuals : 18692
#    Parameters : 1868
#    Iterations : 4
#          Time : 0.0848629 [s]
#  Initial cost : 0.59731 [px]
#    Final cost : 0.591972 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 4
#   => Filtered observations: 0
#   => Changed observations: 0.000384
#
# ==============================================================================
# Registering image #19 (286)
# ==============================================================================
#
#   => Image sees 935 / 4251 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1882
#    Parameters : 6
#    Iterations : 7
#          Time : 0.0130599 [s]
#  Initial cost : 0.486349 [px]
#    Final cost : 0.471943 [px]
#   Termination : Convergence
#
#   => Continued observations: 926
#   => Added observations: 228
#
# Bundle adjustment report
# ------------------------
#     Residuals : 18694
#    Parameters : 1730
#    Iterations : 26
#          Time : 0.529961 [s]
#  Initial cost : 0.508918 [px]
#    Final cost : 0.495822 [px]
#   Termination : No convergence
#
#   => Merged observations: 54
#   => Completed observations: 207
#   => Filtered observations: 43
#   => Changed observations: 0.029284
#
# Bundle adjustment report
# ------------------------
#     Residuals : 18920
#    Parameters : 1691
#    Iterations : 4
#          Time : 0.0859039 [s]
#  Initial cost : 0.606028 [px]
#    Final cost : 0.601609 [px]
#   Termination : Convergence
#
#   => Merged observations: 12
#   => Completed observations: 6
#   => Filtered observations: 1
#   => Changed observations: 0.001810
#
# ==============================================================================
# Registering image #18 (287)
# ==============================================================================
#
#   => Image sees 857 / 3521 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1730
#    Parameters : 6
#    Iterations : 6
#          Time : 0.00988984 [s]
#  Initial cost : 0.486179 [px]
#    Final cost : 0.473442 [px]
#   Termination : Convergence
#
#   => Continued observations: 853
#   => Added observations: 258
#
# Bundle adjustment report
# ------------------------
#     Residuals : 18198
#    Parameters : 1502
#    Iterations : 26
#          Time : 0.526327 [s]
#  Initial cost : 0.512386 [px]
#    Final cost : 0.493974 [px]
#   Termination : No convergence
#
#   => Merged observations: 141
#   => Completed observations: 219
#   => Filtered observations: 42
#   => Changed observations: 0.039431
#
# Bundle adjustment report
# ------------------------
#     Residuals : 18366
#    Parameters : 1454
#    Iterations : 4
#          Time : 0.085279 [s]
#  Initial cost : 0.608348 [px]
#    Final cost : 0.602991 [px]
#   Termination : Convergence
#
#   => Merged observations: 18
#   => Completed observations: 14
#   => Filtered observations: 0
#   => Changed observations: 0.003113
#
# ==============================================================================
# Registering image #17 (288)
# ==============================================================================
#
#   => Image sees 893 / 4090 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1806
#    Parameters : 6
#    Iterations : 6
#          Time : 0.013447 [s]
#  Initial cost : 0.48608 [px]
#    Final cost : 0.480873 [px]
#   Termination : Convergence
#
#   => Continued observations: 888
#   => Added observations: 396
#
# Bundle adjustment report
# ------------------------
#     Residuals : 19012
#    Parameters : 1805
#    Iterations : 26
#          Time : 0.542118 [s]
#  Initial cost : 0.52071 [px]
#    Final cost : 0.502206 [px]
#   Termination : No convergence
#
#   => Merged observations: 60
#   => Completed observations: 335
#   => Filtered observations: 60
#   => Changed observations: 0.042627
#
# Bundle adjustment report
# ------------------------
#     Residuals : 19228
#    Parameters : 1751
#    Iterations : 4
#          Time : 0.135274 [s]
#  Initial cost : 0.616604 [px]
#    Final cost : 0.610242 [px]
#   Termination : Convergence
#
#   => Merged observations: 15
#   => Completed observations: 12
#   => Filtered observations: 3
#   => Changed observations: 0.002764
#
# ==============================================================================
# Registering image #16 (289)
# ==============================================================================
#
#   => Image sees 911 / 4076 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1842
#    Parameters : 6
#    Iterations : 6
#          Time : 0.0106621 [s]
#  Initial cost : 0.474867 [px]
#    Final cost : 0.470832 [px]
#   Termination : Convergence
#
#   => Continued observations: 906
#   => Added observations: 376
#
# Bundle adjustment report
# ------------------------
#     Residuals : 19362
#    Parameters : 1799
#    Iterations : 26
#          Time : 0.52577 [s]
#  Initial cost : 0.5172 [px]
#    Final cost : 0.495687 [px]
#   Termination : No convergence
#
#   => Merged observations: 38
#   => Completed observations: 322
#   => Filtered observations: 65
#   => Changed observations: 0.039134
#
# Bundle adjustment report
# ------------------------
#     Residuals : 19602
#    Parameters : 1715
#    Iterations : 5
#          Time : 0.107796 [s]
#  Initial cost : 0.609328 [px]
#    Final cost : 0.601875 [px]
#   Termination : Convergence
#
#   => Merged observations: 6
#   => Completed observations: 24
#   => Filtered observations: 5
#   => Changed observations: 0.003184
#
# ==============================================================================
# Registering image #15 (290)
# ==============================================================================
#
#   => Image sees 858 / 3697 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1736
#    Parameters : 6
#    Iterations : 9
#          Time : 0.014637 [s]
#  Initial cost : 0.529174 [px]
#    Final cost : 0.472926 [px]
#   Termination : Convergence
#
#   => Continued observations: 848
#   => Added observations: 350
#
# Bundle adjustment report
# ------------------------
#     Residuals : 18696
#    Parameters : 1628
#    Iterations : 26
#          Time : 0.525613 [s]
#  Initial cost : 0.542962 [px]
#    Final cost : 0.499827 [px]
#   Termination : No convergence
#
#   => Merged observations: 185
#   => Completed observations: 315
#   => Filtered observations: 57
#   => Changed observations: 0.052766
#
# Bundle adjustment report
# ------------------------
#     Residuals : 18866
#    Parameters : 1577
#    Iterations : 3
#          Time : 0.064487 [s]
#  Initial cost : 0.613801 [px]
#    Final cost : 0.608918 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 9
#   => Filtered observations: 1
#   => Changed observations: 0.000936
#
# ==============================================================================
# Registering image #14 (291)
# ==============================================================================
#
#   => Image sees 895 / 3656 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1818
#    Parameters : 6
#    Iterations : 7
#          Time : 0.0338771 [s]
#  Initial cost : 0.519813 [px]
#    Final cost : 0.472194 [px]
#   Termination : Convergence
#
#   => Continued observations: 892
#   => Added observations: 326
#
# Bundle adjustment report
# ------------------------
#     Residuals : 18752
#    Parameters : 1610
#    Iterations : 19
#          Time : 0.367033 [s]
#  Initial cost : 0.518861 [px]
#    Final cost : 0.492586 [px]
#   Termination : Convergence
#
#   => Merged observations: 175
#   => Completed observations: 320
#   => Filtered observations: 37
#   => Changed observations: 0.050108
#
# Bundle adjustment report
# ------------------------
#     Residuals : 18904
#    Parameters : 1529
#    Iterations : 4
#          Time : 0.0828331 [s]
#  Initial cost : 0.611232 [px]
#    Final cost : 0.606562 [px]
#   Termination : Convergence
#
#   => Merged observations: 11
#   => Completed observations: 6
#   => Filtered observations: 1
#   => Changed observations: 0.001682
#
# ==============================================================================
# Registering image #13 (292)
# ==============================================================================
#
#   => Image sees 882 / 3676 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1780
#    Parameters : 6
#    Iterations : 8
#          Time : 0.0129759 [s]
#  Initial cost : 0.50832 [px]
#    Final cost : 0.470209 [px]
#   Termination : Convergence
#
#   => Continued observations: 874
#   => Added observations: 383
#
# Bundle adjustment report
# ------------------------
#     Residuals : 18506
#    Parameters : 1583
#    Iterations : 26
#          Time : 0.515801 [s]
#  Initial cost : 0.51703 [px]
#    Final cost : 0.500785 [px]
#   Termination : No convergence
#
#   => Merged observations: 72
#   => Completed observations: 336
#   => Filtered observations: 40
#   => Changed observations: 0.042404
#
# Bundle adjustment report
# ------------------------
#     Residuals : 18868
#    Parameters : 1541
#    Iterations : 4
#          Time : 0.0832591 [s]
#  Initial cost : 0.618681 [px]
#    Final cost : 0.611853 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 3
#   => Filtered observations: 3
#   => Changed observations: 0.000558
#
# ==============================================================================
# Registering image #12 (293)
# ==============================================================================
#
#   => Image sees 950 / 3807 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1920
#    Parameters : 6
#    Iterations : 6
#          Time : 0.015672 [s]
#  Initial cost : 0.47904 [px]
#    Final cost : 0.476566 [px]
#   Termination : Convergence
#
#   => Continued observations: 946
#   => Added observations: 365
#
# Bundle adjustment report
# ------------------------
#     Residuals : 18850
#    Parameters : 1622
#    Iterations : 26
#          Time : 0.528513 [s]
#  Initial cost : 0.520141 [px]
#    Final cost : 0.501244 [px]
#   Termination : No convergence
#
#   => Merged observations: 53
#   => Completed observations: 357
#   => Filtered observations: 37
#   => Changed observations: 0.041550
#
# Bundle adjustment report
# ------------------------
#     Residuals : 19224
#    Parameters : 1574
#    Iterations : 4
#          Time : 0.0870872 [s]
#  Initial cost : 0.620299 [px]
#    Final cost : 0.614664 [px]
#   Termination : Convergence
#
#   => Merged observations: 14
#   => Completed observations: 8
#   => Filtered observations: 1
#   => Changed observations: 0.002101
#
# ==============================================================================
# Registering image #11 (294)
# ==============================================================================
#
#   => Image sees 953 / 3887 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1926
#    Parameters : 6
#    Iterations : 8
#          Time : 0.0140109 [s]
#  Initial cost : 0.487757 [px]
#    Final cost : 0.480869 [px]
#   Termination : Convergence
#
#   => Continued observations: 944
#   => Added observations: 346
#
# Bundle adjustment report
# ------------------------
#     Residuals : 19274
#    Parameters : 1628
#    Iterations : 26
#          Time : 0.697123 [s]
#  Initial cost : 0.520419 [px]
#    Final cost : 0.502771 [px]
#   Termination : No convergence
#
#   => Merged observations: 178
#   => Completed observations: 285
#   => Filtered observations: 55
#   => Changed observations: 0.047384
#
# Bundle adjustment report
# ------------------------
#     Residuals : 19440
#    Parameters : 1562
#    Iterations : 4
#          Time : 0.13399 [s]
#  Initial cost : 0.614316 [px]
#    Final cost : 0.60747 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 5
#   => Filtered observations: 1
#   => Changed observations: 0.000545
#
# ==============================================================================
# Registering image #10 (295)
# ==============================================================================
#
#   => Image sees 1068 / 4673 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2172
#    Parameters : 6
#    Iterations : 8
#          Time : 0.0249202 [s]
#  Initial cost : 0.598375 [px]
#    Final cost : 0.459582 [px]
#   Termination : Convergence
#
#   => Continued observations: 1064
#   => Added observations: 409
#
# Bundle adjustment report
# ------------------------
#     Residuals : 19802
#    Parameters : 1817
#    Iterations : 26
#          Time : 0.879248 [s]
#  Initial cost : 0.503276 [px]
#    Final cost : 0.491228 [px]
#   Termination : No convergence
#
#   => Merged observations: 136
#   => Completed observations: 349
#   => Filtered observations: 36
#   => Changed observations: 0.046518
#
# Bundle adjustment report
# ------------------------
#     Residuals : 20324
#    Parameters : 1793
#    Iterations : 4
#          Time : 0.142626 [s]
#  Initial cost : 0.605671 [px]
#    Final cost : 0.600031 [px]
#   Termination : Convergence
#
#   => Merged observations: 20
#   => Completed observations: 7
#   => Filtered observations: 0
#   => Changed observations: 0.002349
#
# ==============================================================================
# Registering image #9 (296)
# ==============================================================================
#
#   => Image sees 1088 / 5535 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2234
#    Parameters : 6
#    Iterations : 8
#          Time : 0.026154 [s]
#  Initial cost : 0.583256 [px]
#    Final cost : 0.451376 [px]
#   Termination : Convergence
#
#   => Continued observations: 1086
#   => Added observations: 528
#
# Bundle adjustment report
# ------------------------
#     Residuals : 19690
#    Parameters : 1880
#    Iterations : 26
#          Time : 0.863683 [s]
#  Initial cost : 0.510878 [px]
#    Final cost : 0.493873 [px]
#   Termination : No convergence
#
#   => Merged observations: 163
#   => Completed observations: 344
#   => Filtered observations: 36
#   => Changed observations: 0.048271
#
# Bundle adjustment report
# ------------------------
#     Residuals : 20048
#    Parameters : 1826
#    Iterations : 4
#          Time : 0.145941 [s]
#  Initial cost : 0.60525 [px]
#    Final cost : 0.599198 [px]
#   Termination : Convergence
#
#   => Merged observations: 9
#   => Completed observations: 5
#   => Filtered observations: 2
#   => Changed observations: 0.001407
#
# ==============================================================================
# Registering image #8 (297)
# ==============================================================================
#
#   => Image sees 1200 / 6161 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2424
#    Parameters : 6
#    Iterations : 6
#          Time : 0.024086 [s]
#  Initial cost : 0.440322 [px]
#    Final cost : 0.434635 [px]
#   Termination : Convergence
#
#   => Continued observations: 1197
#   => Added observations: 508
#
# Bundle adjustment report
# ------------------------
#     Residuals : 21118
#    Parameters : 2045
#    Iterations : 26
#          Time : 0.676932 [s]
#  Initial cost : 0.495238 [px]
#    Final cost : 0.479338 [px]
#   Termination : No convergence
#
#   => Merged observations: 172
#   => Completed observations: 480
#   => Filtered observations: 33
#   => Changed observations: 0.058135
#
# Bundle adjustment report
# ------------------------
#     Residuals : 21546
#    Parameters : 1988
#    Iterations : 4
#          Time : 0.0899389 [s]
#  Initial cost : 0.592831 [px]
#    Final cost : 0.585973 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 7
#   => Filtered observations: 1
#   => Changed observations: 0.000664
#
# ==============================================================================
# Registering image #7 (298)
# ==============================================================================
#
#   => Image sees 1314 / 7220 points
#
# Pose refinement report
# ----------------------
#     Residuals : 2664
#    Parameters : 6
#    Iterations : 6
#          Time : 0.0149639 [s]
#  Initial cost : 0.427408 [px]
#    Final cost : 0.422203 [px]
#   Termination : Convergence
#
#   => Continued observations: 1313
#   => Added observations: 474
#
# Bundle adjustment report
# ------------------------
#     Residuals : 22006
#    Parameters : 2132
#    Iterations : 12
#          Time : 0.30224 [s]
#  Initial cost : 0.490962 [px]
#    Final cost : 0.478538 [px]
#   Termination : Convergence
#
#   => Merged observations: 292
#   => Completed observations: 458
#   => Filtered observations: 27
#   => Changed observations: 0.063135
#
# Bundle adjustment report
# ------------------------
#     Residuals : 22482
#    Parameters : 2063
#    Iterations : 4
#          Time : 0.0980508 [s]
#  Initial cost : 0.590759 [px]
#    Final cost : 0.585809 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 7
#   => Filtered observations: 3
#   => Changed observations: 0.000797
#
# ==============================================================================
# Registering image #5 (299)
# ==============================================================================
#
#   => Image sees 1484 / 8779 points
#
# Pose refinement report
# ----------------------
#     Residuals : 3024
#    Parameters : 6
#    Iterations : 6
#          Time : 0.0174839 [s]
#  Initial cost : 0.415754 [px]
#    Final cost : 0.409793 [px]
#   Termination : Convergence
#
#   => Continued observations: 1482
#   => Added observations: 527
#
# Bundle adjustment report
# ------------------------
#     Residuals : 23980
#    Parameters : 2486
#    Iterations : 26
#          Time : 0.73003 [s]
#  Initial cost : 0.485227 [px]
#    Final cost : 0.464268 [px]
#   Termination : No convergence
#
#   => Merged observations: 286
#   => Completed observations: 551
#   => Filtered observations: 38
#   => Changed observations: 0.065824
#
# Bundle adjustment report
# ------------------------
#     Residuals : 24710
#    Parameters : 2393
#    Iterations : 4
#          Time : 0.106059 [s]
#  Initial cost : 0.569075 [px]
#    Final cost : 0.562876 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 17
#   => Filtered observations: 2
#   => Changed observations: 0.001398
#
# ==============================================================================
# Registering image #6 (300)
# ==============================================================================
#
#   => Image sees 1625 / 10015 points
#
# Pose refinement report
# ----------------------
#     Residuals : 3296
#    Parameters : 6
#    Iterations : 5
#          Time : 0.0157051 [s]
#  Initial cost : 0.390267 [px]
#    Final cost : 0.386866 [px]
#   Termination : Convergence
#
#   => Continued observations: 1624
#   => Added observations: 395
#
# Bundle adjustment report
# ------------------------
#     Residuals : 25246
#    Parameters : 2585
#    Iterations : 26
#          Time : 0.668895 [s]
#  Initial cost : 0.46342 [px]
#    Final cost : 0.450271 [px]
#   Termination : No convergence
#
#   => Merged observations: 127
#   => Completed observations: 440
#   => Filtered observations: 25
#   => Changed observations: 0.042099
#
# Bundle adjustment report
# ------------------------
#     Residuals : 25836
#    Parameters : 2540
#    Iterations : 4
#          Time : 0.111432 [s]
#  Initial cost : 0.553359 [px]
#    Final cost : 0.54986 [px]
#   Termination : Convergence
#
#   => Merged observations: 21
#   => Completed observations: 4
#   => Filtered observations: 3
#   => Changed observations: 0.001950
#
# ==============================================================================
# Registering image #3 (301)
# ==============================================================================
#
#   => Image sees 1765 / 10994 points
#
# Pose refinement report
# ----------------------
#     Residuals : 3570
#    Parameters : 6
#    Iterations : 5
#          Time : 0.0177851 [s]
#  Initial cost : 0.380126 [px]
#    Final cost : 0.375265 [px]
#   Termination : Convergence
#
#   => Continued observations: 1763
#   => Added observations: 383
#
# Bundle adjustment report
# ------------------------
#     Residuals : 27258
#    Parameters : 2837
#    Iterations : 26
#          Time : 0.713932 [s]
#  Initial cost : 0.45824 [px]
#    Final cost : 0.441887 [px]
#   Termination : No convergence
#
#   => Merged observations: 249
#   => Completed observations: 483
#   => Filtered observations: 36
#   => Changed observations: 0.051811
#
# Bundle adjustment report
# ------------------------
#     Residuals : 27698
#    Parameters : 2744
#    Iterations : 4
#          Time : 0.117757 [s]
#  Initial cost : 0.537673 [px]
#    Final cost : 0.533611 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 3
#   => Filtered observations: 1
#   => Changed observations: 0.000265
#
# ==============================================================================
# Retriangulation
# ==============================================================================
#
#   => Completed observations: 33
#   => Merged observations: 1192
#   => Retriangulated observations: 0
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  2.803894e+05    0.00e+00    2.60e+04   0.00e+00   0.00e+00  1.00e+04        0    7.56e-01    3.81e+00
#
# CHOLMOD version 3.0.14, Oct 22, 2019: Symbolic Analysis: status: OK
#   Architecture: Linux
#     sizeof(int):      4
#     sizeof(SuiteSparse_long):  8
#     sizeof(void *):   8
#     sizeof(double):   8
#     sizeof(Int):      4 (CHOLMOD's basic integer)
#     sizeof(BLAS_INT): 4 (integer used in the BLAS)
#   Results from most recent analysis:
#     Cholesky flop count: 6.9853e+08
#     Nonzeros in L:       1.0366e+06
#   memory blocks in use:          11
#   memory in use (MB):           0.1
#   peak memory usage (MB):       4.1
#   maxrank:    update/downdate rank:   8
#   supernodal control: 1 40 (supernodal if flops/lnz >= 40)
#   nmethods:   number of ordering methods to try: 1
#     method 0: natural
#         flop count: 6.9853e+08
#         nnz(L):     1.0366e+06
#   OK
#    1  2.739142e+05    6.48e+03    3.50e+03   1.92e+00   1.00e+00  3.00e+04        1    7.36e+00    1.12e+01
#    2  2.738965e+05    1.77e+01    1.66e+03   5.85e-01   1.01e+00  9.00e+04        1    3.64e+00    1.48e+01
#    3  2.738945e+05    1.95e+00    4.88e+02   4.06e-01   9.95e-01  2.70e+05        1    3.95e+00    1.88e+01
#    4  2.738940e+05    5.02e-01    1.36e+02   3.37e-01   9.83e-01  8.10e+05        1    5.54e+00    2.43e+01
#    5  2.738940e+05    7.00e-02    4.86e+02   1.14e-01   9.93e-01  2.43e+06        1    3.79e+00    2.81e+01
#    6  2.738939e+05    1.12e-02    3.57e+01   9.04e-02   1.00e+00  7.29e+06        1    3.67e+00    3.17e+01
#    7  2.738939e+05    6.78e-04    1.24e+00   2.80e-02   1.00e+00  2.19e+07        1    5.77e+00    3.75e+01
#    8  2.738939e+05    6.83e-06    1.84e-01   2.94e-03   1.01e+00  6.56e+07        1    3.66e+00    4.12e+01
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 833074
#    Parameters : 130756
#    Iterations : 9
#          Time : 41.2248 [s]
#  Initial cost : 0.580148 [px]
#    Final cost : 0.573389 [px]
#   Termination : Convergence
#
#   => Completed observations: 150
#   => Merged observations: 247
#   => Filtered observations: 86
#   => Changed observations: 0.001160
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  2.742889e+05    0.00e+00    2.09e+04   0.00e+00   0.00e+00  1.00e+04        0    7.38e-01    3.71e+00
#
# CHOLMOD version 3.0.14, Oct 22, 2019: Symbolic Analysis: status: OK
#   Architecture: Linux
#     sizeof(int):      4
#     sizeof(SuiteSparse_long):  8
#     sizeof(void *):   8
#     sizeof(double):   8
#     sizeof(Int):      4 (CHOLMOD's basic integer)
#     sizeof(BLAS_INT): 4 (integer used in the BLAS)
#   Results from most recent analysis:
#     Cholesky flop count: 6.9853e+08
#     Nonzeros in L:       1.0366e+06
#   memory blocks in use:          11
#   memory in use (MB):           0.1
#   peak memory usage (MB):       4.1
#   maxrank:    update/downdate rank:   8
#   supernodal control: 1 40 (supernodal if flops/lnz >= 40)
#   nmethods:   number of ordering methods to try: 1
#     method 0: natural
#         flop count: 6.9853e+08
#         nnz(L):     1.0366e+06
#   OK
#    1  2.741035e+05    1.85e+02    4.08e+02   5.72e-01   1.00e+00  3.00e+04        1    7.41e+00    1.11e+01
#    2  2.741028e+05    6.63e-01    8.37e+01   1.10e-01   1.01e+00  9.00e+04        1    3.74e+00    1.49e+01
#    3  2.741028e+05    3.71e-02    4.44e+01   5.19e-02   1.00e+00  2.70e+05        1    3.73e+00    1.86e+01
#    4  2.741028e+05    7.44e-03    2.48e+01   3.91e-02   9.89e-01  8.10e+05        1    5.59e+00    2.42e+01
#    5  2.741028e+05    8.53e-04    1.11e+01   1.20e-02   9.94e-01  2.43e+06        1    3.79e+00    2.80e+01
#    6  2.741028e+05    1.31e-04    8.05e-01   9.30e-03   1.00e+00  7.29e+06        1    3.64e+00    3.16e+01
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 833196
#    Parameters : 130735
#    Iterations : 7
#          Time : 31.6507 [s]
#  Initial cost : 0.57376 [px]
#    Final cost : 0.573566 [px]
#   Termination : Convergence
#
#   => Completed observations: 35
#   => Merged observations: 0
#   => Filtered observations: 20
#   => Changed observations: 0.000132
#   => Filtered images: 0
#
# ==============================================================================
# Registering image #4 (302)
# ==============================================================================
#
#   => Image sees 1843 / 11324 points
#
# Pose refinement report
# ----------------------
#     Residuals : 3720
#    Parameters : 6
#    Iterations : 5
#          Time : 0.0284932 [s]
#  Initial cost : 0.316991 [px]
#    Final cost : 0.315165 [px]
#   Termination : Convergence
#
#   => Continued observations: 1842
#   => Added observations: 361
#
# Bundle adjustment report
# ------------------------
#     Residuals : 28926
#    Parameters : 2885
#    Iterations : 18
#          Time : 0.798212 [s]
#  Initial cost : 0.405465 [px]
#    Final cost : 0.396315 [px]
#   Termination : Convergence
#
#   => Merged observations: 126
#   => Completed observations: 404
#   => Filtered observations: 18
#   => Changed observations: 0.035072
#
# Bundle adjustment report
# ------------------------
#     Residuals : 29406
#    Parameters : 2837
#    Iterations : 7
#          Time : 0.318656 [s]
#  Initial cost : 0.477321 [px]
#    Final cost : 0.474166 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 13
#   => Filtered observations: 0
#   => Changed observations: 0.000819
#
# ==============================================================================
# Registering image #2 (303)
# ==============================================================================
#
#   => Image sees 1733 / 13754 points
#
# Pose refinement report
# ----------------------
#     Residuals : 3494
#    Parameters : 6
#    Iterations : 5
#          Time : 0.0272222 [s]
#  Initial cost : 0.329277 [px]
#    Final cost : 0.327286 [px]
#   Termination : Convergence
#
#   => Continued observations: 1732
#   => Added observations: 293
#
# Bundle adjustment report
# ------------------------
#     Residuals : 28252
#    Parameters : 2555
#    Iterations : 26
#          Time : 1.18647 [s]
#  Initial cost : 0.423382 [px]
#    Final cost : 0.399809 [px]
#   Termination : No convergence
#
#   => Merged observations: 254
#   => Completed observations: 386
#   => Filtered observations: 30
#   => Changed observations: 0.043657
#
# Bundle adjustment report
# ------------------------
#     Residuals : 27942
#    Parameters : 2453
#    Iterations : 3
#          Time : 0.144958 [s]
#  Initial cost : 0.486698 [px]
#    Final cost : 0.483765 [px]
#   Termination : Convergence
#
#   => Merged observations: 15
#   => Completed observations: 17
#   => Filtered observations: 1
#   => Changed observations: 0.002136
#
# ==============================================================================
# Registering image #1 (304)
# ==============================================================================
#
#   => Image sees 1837 / 13472 points
#
# Pose refinement report
# ----------------------
#     Residuals : 3690
#    Parameters : 6
#    Iterations : 6
#          Time : 0.0420921 [s]
#  Initial cost : 0.465591 [px]
#    Final cost : 0.323805 [px]
#   Termination : Convergence
#
#   => Continued observations: 1834
#   => Added observations: 285
#
# Bundle adjustment report
# ------------------------
#     Residuals : 29286
#    Parameters : 2666
#    Iterations : 26
#          Time : 0.643089 [s]
#  Initial cost : 0.453841 [px]
#    Final cost : 0.397258 [px]
#   Termination : No convergence
#
#   => Merged observations: 79
#   => Completed observations: 411
#   => Filtered observations: 47
#   => Changed observations: 0.033702
#
# Bundle adjustment report
# ------------------------
#     Residuals : 29558
#    Parameters : 2537
#    Iterations : 3
#          Time : 0.111573 [s]
#  Initial cost : 0.477476 [px]
#    Final cost : 0.474483 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 0
#   => Filtered observations: 0
#   => Changed observations: 0.000000
#
# ==============================================================================
# Registering image #305 (305)
# ==============================================================================
#
#   => Image sees 543 / 2536 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1102
#    Parameters : 6
#    Iterations : 10
#          Time : 0.00992513 [s]
#  Initial cost : 0.561173 [px]
#    Final cost : 0.522916 [px]
#   Termination : Convergence
#
#   => Continued observations: 533
#   => Added observations: 377
#
# Bundle adjustment report
# ------------------------
#     Residuals : 12084
#    Parameters : 1706
#    Iterations : 20
#          Time : 0.284294 [s]
#  Initial cost : 0.513254 [px]
#    Final cost : 0.501144 [px]
#   Termination : Convergence
#
#   => Merged observations: 129
#   => Completed observations: 95
#   => Filtered observations: 45
#   => Changed observations: 0.039173
#
# Bundle adjustment report
# ------------------------
#     Residuals : 12032
#    Parameters : 1676
#    Iterations : 4
#          Time : 0.0584941 [s]
#  Initial cost : 0.617142 [px]
#    Final cost : 0.610872 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 2
#   => Filtered observations: 1
#   => Changed observations: 0.000434
#
# ==============================================================================
# Registering image #306 (306)
# ==============================================================================
#
#   => Image sees 519 / 2535 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1052
#    Parameters : 6
#    Iterations : 11
#          Time : 0.010391 [s]
#  Initial cost : 0.614638 [px]
#    Final cost : 0.5258 [px]
#   Termination : Convergence
#
#   => Continued observations: 513
#   => Added observations: 334
#
# Bundle adjustment report
# ------------------------
#     Residuals : 11854
#    Parameters : 1541
#    Iterations : 26
#          Time : 0.372045 [s]
#  Initial cost : 0.523862 [px]
#    Final cost : 0.513524 [px]
#   Termination : No convergence
#
#   => Merged observations: 71
#   => Completed observations: 92
#   => Filtered observations: 37
#   => Changed observations: 0.029709
#
# Bundle adjustment report
# ------------------------
#     Residuals : 11914
#    Parameters : 1523
#    Iterations : 4
#          Time : 0.0553639 [s]
#  Initial cost : 0.620722 [px]
#    Final cost : 0.613246 [px]
#   Termination : Convergence
#
#   => Merged observations: 44
#   => Completed observations: 11
#   => Filtered observations: 0
#   => Changed observations: 0.008135
#
# ==============================================================================
# Registering image #307 (307)
# ==============================================================================
#
#   => Image sees 538 / 2553 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1086
#    Parameters : 6
#    Iterations : 11
#          Time : 0.010397 [s]
#  Initial cost : 0.602055 [px]
#    Final cost : 0.519692 [px]
#   Termination : Convergence
#
#   => Continued observations: 524
#   => Added observations: 346
#
# Bundle adjustment report
# ------------------------
#     Residuals : 11198
#    Parameters : 1622
#    Iterations : 16
#          Time : 0.234721 [s]
#  Initial cost : 0.521685 [px]
#    Final cost : 0.504572 [px]
#   Termination : Convergence
#
#   => Merged observations: 98
#   => Completed observations: 91
#   => Filtered observations: 29
#   => Changed observations: 0.033569
#
# Bundle adjustment report
# ------------------------
#     Residuals : 11314
#    Parameters : 1601
#    Iterations : 4
#          Time : 0.0541391 [s]
#  Initial cost : 0.625132 [px]
#    Final cost : 0.617504 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 6
#   => Filtered observations: 3
#   => Changed observations: 0.001374
#
# ==============================================================================
# Registering image #308 (308)
# ==============================================================================
#
#   => Image sees 554 / 2581 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1128
#    Parameters : 6
#    Iterations : 8
#          Time : 0.00831318 [s]
#  Initial cost : 0.574544 [px]
#    Final cost : 0.498808 [px]
#   Termination : Convergence
#
#   => Continued observations: 546
#   => Added observations: 403
#
# Bundle adjustment report
# ------------------------
#     Residuals : 11424
#    Parameters : 1724
#    Iterations : 26
#          Time : 0.350706 [s]
#  Initial cost : 0.516093 [px]
#    Final cost : 0.503821 [px]
#   Termination : No convergence
#
#   => Merged observations: 191
#   => Completed observations: 105
#   => Filtered observations: 22
#   => Changed observations: 0.048461
#
# Bundle adjustment report
# ------------------------
#     Residuals : 11564
#    Parameters : 1709
#    Iterations : 4
#          Time : 0.0593681 [s]
#  Initial cost : 0.625384 [px]
#    Final cost : 0.618921 [px]
#   Termination : Convergence
#
#   => Merged observations: 15
#   => Completed observations: 2
#   => Filtered observations: 0
#   => Changed observations: 0.002563
#
# ==============================================================================
# Registering image #310 (309)
# ==============================================================================
#
#   => Image sees 613 / 2471 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1248
#    Parameters : 6
#    Iterations : 8
#          Time : 0.00962996 [s]
#  Initial cost : 0.514527 [px]
#    Final cost : 0.5065 [px]
#   Termination : Convergence
#
#   => Continued observations: 604
#   => Added observations: 449
#
# Bundle adjustment report
# ------------------------
#     Residuals : 11534
#    Parameters : 1844
#    Iterations : 26
#          Time : 0.357417 [s]
#  Initial cost : 0.523636 [px]
#    Final cost : 0.508224 [px]
#   Termination : No convergence
#
#   => Merged observations: 63
#   => Completed observations: 103
#   => Filtered observations: 42
#   => Changed observations: 0.031410
#
# Bundle adjustment report
# ------------------------
#     Residuals : 11610
#    Parameters : 1823
#    Iterations : 4
#          Time : 0.057544 [s]
#  Initial cost : 0.622107 [px]
#    Final cost : 0.61547 [px]
#   Termination : Convergence
#
#   => Merged observations: 32
#   => Completed observations: 6
#   => Filtered observations: 0
#   => Changed observations: 0.005704
#
# ==============================================================================
# Registering image #309 (310)
# ==============================================================================
#
#   => Image sees 541 / 2114 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1108
#    Parameters : 6
#    Iterations : 11
#          Time : 0.012109 [s]
#  Initial cost : 0.678006 [px]
#    Final cost : 0.544544 [px]
#   Termination : Convergence
#
#   => Continued observations: 528
#   => Added observations: 325
#
# Bundle adjustment report
# ------------------------
#     Residuals : 11380
#    Parameters : 1637
#    Iterations : 26
#          Time : 0.3642 [s]
#  Initial cost : 0.533308 [px]
#    Final cost : 0.517447 [px]
#   Termination : No convergence
#
#   => Merged observations: 141
#   => Completed observations: 96
#   => Filtered observations: 61
#   => Changed observations: 0.046723
#
# Bundle adjustment report
# ------------------------
#     Residuals : 11250
#    Parameters : 1598
#    Iterations : 4
#          Time : 0.0584581 [s]
#  Initial cost : 0.632681 [px]
#    Final cost : 0.626573 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 10
#   => Filtered observations: 1
#   => Changed observations: 0.001716
#
# ==============================================================================
# Registering image #312 (311)
# ==============================================================================
#
#   => Image sees 592 / 2183 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1220
#    Parameters : 6
#    Iterations : 11
#          Time : 0.0119741 [s]
#  Initial cost : 0.562399 [px]
#    Final cost : 0.531716 [px]
#   Termination : Convergence
#
#   => Continued observations: 585
#   => Added observations: 369
#
# Bundle adjustment report
# ------------------------
#     Residuals : 11646
#    Parameters : 1877
#    Iterations : 14
#          Time : 0.194184 [s]
#  Initial cost : 0.526986 [px]
#    Final cost : 0.513867 [px]
#   Termination : Convergence
#
#   => Merged observations: 96
#   => Completed observations: 101
#   => Filtered observations: 45
#   => Changed observations: 0.036756
#
# Bundle adjustment report
# ------------------------
#     Residuals : 11810
#    Parameters : 1865
#    Iterations : 3
#          Time : 0.042733 [s]
#  Initial cost : 0.63449 [px]
#    Final cost : 0.625791 [px]
#   Termination : Convergence
#
#   => Merged observations: 46
#   => Completed observations: 7
#   => Filtered observations: 0
#   => Changed observations: 0.007951
#
# ==============================================================================
# Registering image #311 (312)
# ==============================================================================
#
#   => Image sees 603 / 2216 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1246
#    Parameters : 6
#    Iterations : 8
#          Time : 0.00899601 [s]
#  Initial cost : 0.574765 [px]
#    Final cost : 0.523808 [px]
#   Termination : Convergence
#
#   => Continued observations: 594
#   => Added observations: 388
#
# Bundle adjustment report
# ------------------------
#     Residuals : 12158
#    Parameters : 1919
#    Iterations : 21
#          Time : 0.30433 [s]
#  Initial cost : 0.513758 [px]
#    Final cost : 0.502781 [px]
#   Termination : Convergence
#
#   => Merged observations: 205
#   => Completed observations: 116
#   => Filtered observations: 48
#   => Changed observations: 0.054377
#
# Bundle adjustment report
# ------------------------
#     Residuals : 12260
#    Parameters : 1886
#    Iterations : 4
#          Time : 0.078521 [s]
#  Initial cost : 0.626069 [px]
#    Final cost : 0.618116 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 10
#   => Filtered observations: 0
#   => Changed observations: 0.001462
#
# ==============================================================================
# Registering image #313 (313)
# ==============================================================================
#
#   => Image sees 627 / 2076 points
#
# Pose refinement report
# ----------------------
#     Residuals : 1292
#    Parameters : 6
#    Iterations : 9
#          Time : 0.0104868 [s]
#  Initial cost : 0.533946 [px]
#    Final cost : 0.516717 [px]
#   Termination : Convergence
#
#   => Continued observations: 621
#   => Added observations: 326
#
# Bundle adjustment report
# ------------------------
#     Residuals : 12262
#    Parameters : 1904
#    Iterations : 26
#          Time : 0.381076 [s]
# ...
#         flop count: 1.1387e+09
#         nnz(L):     1.4499e+06
#   OK
#    1  3.211653e+05    1.72e+04    3.51e+08   2.98e+00   8.73e-01  1.71e+04        1    8.28e+00    1.28e+01
#    2  3.194458e+05    1.72e+03    1.79e+08   1.38e+00   7.07e-01  1.84e+04        1    4.65e+00    1.75e+01
#    3  3.201004e+05   -6.55e+02    1.79e+08   1.42e+00  -9.64e-01  9.21e+03        1    5.82e+00    2.33e+01
#    4  3.226206e+05   -3.17e+03    1.79e+08   1.14e+00  -4.97e+00  2.30e+03        1    3.85e+00    2.71e+01
#    5  3.191410e+05    3.05e+02    9.72e+07   6.17e-01   5.72e-01  2.31e+03        1    4.46e+00    3.16e+01
#    6  3.188757e+05    2.65e+02    1.10e+08   5.18e-01   9.75e-01  6.93e+03        1    6.71e+00    3.83e+01
#    7  3.188021e+05    7.36e+01    4.66e+08   9.60e-01   8.73e-01  1.18e+04        1    4.50e+00    4.28e+01
#    8  3.187547e+05    4.75e+01    6.75e+07   1.19e+00   8.77e-01  2.07e+04        1    4.61e+00    4.74e+01
#    9  3.187220e+05    3.26e+01    1.60e+08   1.50e+00   8.64e-01  3.38e+04        1    6.59e+00    5.40e+01
#   10  3.187005e+05    2.16e+01    6.02e+08   1.79e+00   8.63e-01  5.47e+04        1    4.65e+00    5.87e+01
#   11  3.186859e+05    1.45e+01    1.97e+08   2.06e+00   8.63e-01  8.84e+04        1    4.88e+00    6.35e+01
#   12  3.186759e+05    1.01e+01    5.31e+08   2.32e+00   8.62e-01  1.42e+05        1    6.29e+00    6.98e+01
#   13  3.186687e+05    7.16e+00    4.49e+08   2.51e+00   8.57e-01  2.24e+05        1    4.47e+00    7.43e+01
#   14  3.186636e+05    5.17e+00    2.30e+08   2.61e+00   8.57e-01  3.53e+05        1    6.11e+00    8.04e+01
#   15  3.186560e+05    7.52e+00    1.39e+08   2.66e+00   9.64e-01  1.06e+06        1    4.99e+00    8.54e+01
#   16  3.186405e+05    1.56e+01    1.94e+08   3.91e+00   7.65e-01  1.24e+06        1    4.61e+00    9.00e+01
#   17  3.186333e+05    7.18e+00    4.08e+08   3.47e+00   7.25e-01  1.37e+06        1    6.60e+00    9.66e+01
#   18  3.186294e+05    3.84e+00    3.63e+08   3.71e+00   8.32e-01  1.94e+06        1    4.51e+00    1.01e+02
#   19  3.186283e+05    1.17e+00    4.48e+08   5.14e+00   8.18e-01  2.61e+06        1    4.47e+00    1.06e+02
#   20  3.186279e+05    3.87e-01    4.29e+08   6.76e+00   7.99e-01  3.32e+06        1    6.73e+00    1.12e+02
#   21  3.186277e+05    1.66e-01    8.99e+07   8.44e+00   7.92e-01  4.15e+06        1    4.54e+00    1.17e+02
#   22  3.186276e+05    8.96e-02    1.97e+08   1.03e+01   7.96e-01  5.23e+06        1    5.03e+00    1.22e+02
#   23  3.186276e+05    5.59e-02    5.49e+08   1.28e+01   7.99e-01  6.65e+06        1    6.10e+00    1.28e+02
#   24  3.186275e+05    3.79e-02    5.59e+08   1.61e+01   8.02e-01  8.53e+06        1    4.48e+00    1.32e+02
#   25  3.186275e+05    2.70e-02    2.28e+08   2.04e+01   8.02e-01  1.09e+07        1    5.88e+00    1.38e+02
#   26  3.186275e+05    1.96e-02    2.42e+08   2.25e+01   8.07e-01  1.42e+07        1    5.25e+00    1.44e+02
#   27  3.186275e+05    1.42e-02    3.79e+08   2.20e+01   8.12e-01  1.88e+07        1    4.56e+00    1.48e+02
#   28  3.186275e+05    1.01e-02    2.14e+08   2.31e+01   8.24e-01  2.58e+07        1    6.53e+00    1.55e+02
#   29  3.186275e+05    7.28e-03    7.26e+08   2.34e+01   8.38e-01  3.74e+07        1    4.58e+00    1.59e+02
#   30  3.186275e+05    5.36e-03    1.45e+08   2.53e+01   8.60e-01  5.96e+07        1    4.46e+00    1.64e+02
#   31  3.186275e+05    4.61e-03    3.86e+08   3.12e+01   8.53e-01  9.21e+07        1    6.65e+00    1.70e+02
#   32  3.186274e+05    3.80e-03    6.31e+08   3.72e+01   8.51e-01  1.41e+08        1    4.50e+00    1.75e+02
#   33  3.186274e+05    3.05e-03    4.24e+08   4.28e+01   8.59e-01  2.24e+08        1    4.75e+00    1.80e+02
#   34  3.186274e+05    2.55e-03    4.07e+08   5.00e+01   8.62e-01  3.62e+08        1    6.43e+00    1.86e+02
#   35  3.186274e+05    2.19e-03    4.71e+08   5.96e+01   8.60e-01  5.76e+08        1    4.63e+00    1.91e+02
#   36  3.186274e+05    1.85e-03    3.31e+08   6.97e+01   8.59e-01  9.15e+08        1    5.33e+00    1.96e+02
#   37  3.186274e+05    1.57e-03    2.74e+08   8.13e+01   8.59e-01  1.45e+09        1    5.81e+00    2.02e+02
#   38  3.186274e+05    1.33e-03    1.82e+08   9.47e+01   8.59e-01  2.30e+09        1    4.52e+00    2.06e+02
#   39  3.186274e+05    1.13e-03    4.07e+08   1.10e+02   8.58e-01  3.64e+09        1    6.67e+00    2.13e+02
#   40  3.186274e+05    9.68e-04    2.84e+08   1.28e+02   8.59e-01  5.76e+09        1    4.50e+00    2.18e+02
#   41  3.186274e+05    8.29e-04    5.20e+08   1.49e+02   8.58e-01  9.12e+09        1    4.49e+00    2.22e+02
#   42  3.186274e+05    7.09e-04    2.65e+08   1.74e+02   8.58e-01  1.44e+10        1    6.63e+00    2.29e+02
#   43  3.186274e+05    6.09e-04    2.19e+08   2.03e+02   8.58e-01  2.29e+10        1    4.58e+00    2.33e+02
#   44  3.186274e+05    5.22e-04    2.63e+08   2.36e+02   8.58e-01  3.62e+10        1    4.64e+00    2.38e+02
#   45  3.186274e+05    4.48e-04    4.09e+08   2.75e+02   8.58e-01  5.72e+10        1    6.44e+00    2.44e+02
#   46  3.186274e+05    3.84e-04    2.63e+07   3.20e+02   8.59e-01  9.07e+10        1    4.44e+00    2.49e+02
#   47  3.186274e+05    3.31e-04    3.82e+07   3.74e+02   8.59e-01  1.44e+11        1    5.44e+00    2.54e+02
#   48  3.186274e+05    2.86e-04    2.36e+07   4.36e+02   8.60e-01  2.29e+11        1    5.46e+00    2.60e+02
#   49  3.186274e+05    2.56e-04    8.34e+06   5.11e+02   8.63e-01  3.71e+11        1    4.57e+00    2.64e+02
#   50  3.186274e+05    3.15e-04    1.18e+06   6.10e+02   8.97e-01  7.43e+11        1    6.19e+00    2.70e+02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 971904
#    Parameters : 152602
#    Iterations : 51
#          Time : 270.488 [s]
#  Initial cost : 0.59005 [px]
#    Final cost : 0.572572 [px]
#   Termination : No convergence
#
#   => Completed observations: 161
#   => Merged observations: 283
#   => Filtered observations: 128
#   => Changed observations: 0.001177
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  3.167055e+05    0.00e+00    1.22e+06   0.00e+00   0.00e+00  1.00e+04        0    8.43e-01    4.59e+00
#
# CHOLMOD version 3.0.14, Oct 22, 2019: Symbolic Analysis: status: OK
#   Architecture: Linux
#     sizeof(int):      4
#     sizeof(SuiteSparse_long):  8
#     sizeof(void *):   8
#     sizeof(double):   8
#     sizeof(Int):      4 (CHOLMOD's basic integer)
#     sizeof(BLAS_INT): 4 (integer used in the BLAS)
#   Results from most recent analysis:
#     Cholesky flop count: 1.1386e+09
#     Nonzeros in L:       1.4498e+06
#   memory blocks in use:          11
#   memory in use (MB):           0.1
#   peak memory usage (MB):       5.7
#   maxrank:    update/downdate rank:   8
#   supernodal control: 1 40 (supernodal if flops/lnz >= 40)
#   nmethods:   number of ordering methods to try: 1
#     method 0: natural
#         flop count: 1.1386e+09
#         nnz(L):     1.4498e+06
#   OK
#    1  3.164540e+05    2.51e+02    2.88e+05   2.01e+00   9.97e-01  3.00e+04        1    9.39e+00    1.40e+01
#    2  3.164496e+05    4.40e+00    6.28e+05   2.70e-01   9.98e-01  9.00e+04        1    4.47e+00    1.85e+01
#    3  3.164488e+05    8.22e-01    1.05e+05   3.78e-02   9.90e-01  2.70e+05        1    5.05e+00    2.35e+01
#    4  3.164486e+05    1.87e-01    3.66e+05   3.16e-02   1.01e+00  8.10e+05        1    6.04e+00    2.95e+01
#    5  3.164486e+05    3.32e-02    2.38e+05   2.88e-02   1.00e+00  2.43e+06        1    4.51e+00    3.40e+01
#    6  3.164486e+05    3.99e-03    4.23e+05   1.62e-02   1.00e+00  7.29e+06        1    5.55e+00    3.96e+01
#    7  3.164486e+05    1.66e-04    3.95e+05   4.08e-03   1.00e+00  2.19e+07        1    5.40e+00    4.50e+01
#    8  3.164486e+05    1.41e-06    3.63e+05   3.64e-04   1.01e+00  6.56e+07        1    4.51e+00    4.95e+01
#    9  3.164486e+05    4.81e-07    1.49e+05   1.12e-05   1.00e+00  1.97e+08        1    6.57e+00    5.61e+01
#   10  3.164486e+05    1.45e-06    4.48e+05   4.32e-07   1.00e+00  5.90e+08        1    4.43e+00    6.05e+01
#   11  3.164486e+05    4.47e-06    1.54e+05   7.43e-07   1.00e+00  1.77e+09        1    4.56e+00    6.51e+01
#   12  3.164486e+05    1.45e-05    1.51e+05   2.41e-06   1.00e+00  5.31e+09        1    6.51e+00    7.16e+01
#   13  3.164486e+05    5.55e-05    1.74e+05   9.20e-06   1.00e+00  1.59e+10        1    4.55e+00    7.61e+01
#   14  3.164486e+05    3.42e-04    1.02e+05   5.68e-05   1.00e+00  4.78e+10        1    4.70e+00    8.08e+01
#   15  3.164486e+05    8.21e-03    1.81e+05   1.37e-03   1.00e+00  1.43e+11        1    6.42e+00    8.73e+01
#   16  3.164502e+05   -1.61e+00    1.81e+05   2.13e-01  -1.63e+00  7.17e+10        1    3.65e+00    9.09e+01
#   17  3.227645e+05   -6.32e+03    1.81e+05   1.43e-01  -9.18e+03  1.79e+10        1    3.63e+00    9.45e+01
#   18  3.164483e+05    3.19e-01    1.77e+06   6.52e-02   9.75e-01  5.38e+10        1    6.64e+00    1.01e+02
#   19  3.164683e+05   -2.00e+01    1.77e+06   8.40e-01  -8.62e+00  2.69e+10        1    3.67e+00    1.05e+02
#   20  3.164548e+05   -6.58e+00    1.77e+06   7.89e-01  -2.90e+00  6.73e+09        1    3.73e+00    1.09e+02
#   21  3.164479e+05    3.76e-01    1.74e+07   5.53e-01   2.01e-01  5.54e+09        1    6.44e+00    1.15e+02
#   22  3.164461e+05    1.76e+00    1.53e+06   1.91e-01   9.91e-01  1.66e+10        1    4.58e+00    1.20e+02
#   23  3.164461e+05    5.47e-02    3.72e+06   1.24e-01   4.32e-01  1.66e+10        1    4.82e+00    1.24e+02
#   24  3.164460e+05    7.99e-02    1.17e+06   2.86e-02   9.31e-01  4.63e+10        1    6.27e+00    1.31e+02
#   25  3.164460e+05    9.75e-03    8.99e+05   4.03e-02   7.38e-01  5.19e+10        1    4.38e+00    1.35e+02
#   26  3.164460e+05    4.77e-03    1.33e+05   2.07e-02   9.84e-01  1.56e+11        1    5.61e+00    1.41e+02
#   27  3.164460e+05    3.34e-04    3.54e+04   1.18e-02   9.85e-01  4.67e+11        1    5.47e+00    1.46e+02
#   28  3.164460e+05    1.51e-05    1.57e+03   2.53e-03   1.00e+00  1.40e+12        1    4.61e+00    1.51e+02
#   29  3.164460e+05    7.07e-08    9.64e+00   1.98e-04   1.06e+00  4.20e+12        1    7.89e+00    1.59e+02
#   30  3.164460e+05   -3.49e-10    9.64e+00   6.13e-06  -4.10e+00  2.10e+12        1    3.89e+00    1.63e+02
#   31  3.164460e+05    1.16e-09    3.91e-01   6.08e-06   1.72e+01  6.30e+12        1    4.45e+00    1.67e+02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 971774
#    Parameters : 152476
#    Iterations : 32
#          Time : 167.05 [s]
#  Initial cost : 0.57088 [px]
#    Final cost : 0.570646 [px]
#   Termination : Convergence
#
#   => Completed observations: 23
#   => Merged observations: 184
#   => Filtered observations: 15
#   => Changed observations: 0.000457
#   => Filtered images: 0
#
# ==============================================================================
# Registering image #364 (367)
# ==============================================================================
#
#   => Image sees 436 / 2262 points
#
# Pose refinement report
# ----------------------
#     Residuals : 898
#    Parameters : 6
#    Iterations : 8
#          Time : 0.0120409 [s]
#  Initial cost : 0.513261 [px]
#    Final cost : 0.499272 [px]
#   Termination : Convergence
#
#   => Continued observations: 435
#   => Added observations: 371
#
# Bundle adjustment report
# ------------------------
#     Residuals : 11628
#    Parameters : 1127
#    Iterations : 26
#          Time : 0.352728 [s]
#  Initial cost : 0.626648 [px]
#    Final cost : 0.520543 [px]
#   Termination : No convergence
#
#   => Merged observations: 49
#   => Completed observations: 346
#   => Filtered observations: 72
#   => Changed observations: 0.069401
#
# Bundle adjustment report
# ------------------------
#     Residuals : 11664
#    Parameters : 1004
#    Iterations : 6
#          Time : 0.180205 [s]
#  Initial cost : 0.639515 [px]
#    Final cost : 0.631433 [px]
#   Termination : Convergence
#
#   => Merged observations: 0
#   => Completed observations: 12
#   => Filtered observations: 3
#   => Changed observations: 0.002222
#
# ==============================================================================
# Registering image #357 (368)
# ==============================================================================
#
#   => Image sees 367 / 875 points
#
# Pose refinement report
# ----------------------
#     Residuals : 764
#    Parameters : 6
#    Iterations : 11
#          Time : 0.0220821 [s]
#  Initial cost : 0.742278 [px]
#    Final cost : 0.540944 [px]
#   Termination : Convergence
#
#   => Continued observations: 364
#   => Added observations: 150
#
# Bundle adjustment report
# ------------------------
#     Residuals : 9836
#    Parameters : 749
#    Iterations : 13
#          Time : 0.283043 [s]
#  Initial cost : 0.526829 [px]
#    Final cost : 0.521497 [px]
#   Termination : Convergence
#
#   => Merged observations: 51
#   => Completed observations: 212
#   => Filtered observations: 30
#   => Changed observations: 0.053831
#
# Bundle adjustment report
# ------------------------
#     Residuals : 9758
#    Parameters : 677
#    Iterations : 4
#          Time : 0.0753479 [s]
#  Initial cost : 0.648737 [px]
#    Final cost : 0.641307 [px]
#   Termination : Convergence
#
#   => Merged observations: 5
#   => Completed observations: 10
#   => Filtered observations: 3
#   => Changed observations: 0.003191
#
# ==============================================================================
# Retriangulation
# ==============================================================================
#
#   => Completed observations: 8
#   => Merged observations: 51
#   => Retriangulated observations: 0
#
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  3.181329e+05    0.00e+00    6.22e+04   0.00e+00   0.00e+00  1.00e+04        0    8.58e-01    4.85e+00
#
# CHOLMOD version 3.0.14, Oct 22, 2019: Symbolic Analysis: status: OK
#   Architecture: Linux
#     sizeof(int):      4
#     sizeof(SuiteSparse_long):  8
#     sizeof(void *):   8
#     sizeof(double):   8
#     sizeof(Int):      4 (CHOLMOD's basic integer)
#     sizeof(BLAS_INT): 4 (integer used in the BLAS)
#   Results from most recent analysis:
#     Cholesky flop count: 1.1482e+09
#     Nonzeros in L:       1.4606e+06
#   memory blocks in use:          11
#   memory in use (MB):           0.1
#   peak memory usage (MB):       5.7
#   maxrank:    update/downdate rank:   8
#   supernodal control: 1 40 (supernodal if flops/lnz >= 40)
#   nmethods:   number of ordering methods to try: 1
#     method 0: natural
#         flop count: 1.1482e+09
#         nnz(L):     1.4606e+06
#   OK
#    1  3.179228e+05    2.10e+02    2.95e+02   5.11e-01   9.99e-01  3.00e+04        1    8.10e+00    1.30e+01
#    2  3.179221e+05    7.24e-01    6.69e+01   1.62e-01   1.00e+00  9.00e+04        1    5.70e+00    1.87e+01
#    3  3.179220e+05    4.86e-02    1.02e+02   4.55e-02   1.00e+00  2.70e+05        1    4.48e+00    2.31e+01
#    4  3.179220e+05    2.88e-02    2.20e+02   3.77e-02   9.97e-01  8.10e+05        1    6.36e+00    2.95e+01
#    5  3.179220e+05    2.47e-02    2.99e+02   5.42e-02   9.90e-01  2.43e+06        1    4.69e+00    3.42e+01
#    6  3.179219e+05    7.96e-03    1.18e+02   4.08e-02   9.84e-01  7.29e+06        1    4.62e+00    3.88e+01
#    7  3.179219e+05    5.33e-04    6.81e+00   1.24e-02   9.83e-01  2.19e+07        1    6.51e+00    4.53e+01
#    8  3.179219e+05    4.87e-06    1.03e+00   1.22e-03   1.00e+00  6.56e+07        1    4.53e+00    4.98e+01
#    9  3.179219e+05    6.05e-09    7.36e-02   4.63e-05   7.82e-01  7.99e+07        1    4.65e+00    5.45e+01
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 975012
#    Parameters : 152752
#    Iterations : 10
#          Time : 54.5685 [s]
#  Initial cost : 0.571215 [px]
#    Final cost : 0.571025 [px]
#   Termination : Convergence
#
#   => Completed observations: 12
#   => Merged observations: 0
#   => Filtered observations: 9
#   => Changed observations: 0.000043
#   => Filtered images: 0
#
# Elapsed time: 33.419 [minutes]

# %%
import os
workspace_dir = "/content/drive/MyDrive/3DCV/HW2/COLMAP"
database_path = f"{workspace_dir}/database/database.db"
frames_dir = f"{workspace_dir}/frames"
sparse_dir = f"{workspace_dir}/output/sparse"

# %% [markdown]
# # **Generating PLY Model format from the final results**

# %%
# Check 3D model
if os.path.exists(f"{sparse_dir}/0"):
    print(" RECONSTRUCTION SUCCESSFUL!")

    # Analyzing final model
    print(" Analyze 3D Model:")
    # !colmap model_analyzer --path "{sparse_dir}/0"

    # Convert to PLY
    print(" Convert to PLY...")
    # !colmap model_converter \
        --input_path "{sparse_dir}/0" \
        --output_path "{workspace_dir}/output/model.ply" \
        --output_type PLY

    print(f"Final Model: {workspace_dir}/output/model.ply")

    # Final output file
    if os.path.exists(f"{workspace_dir}/output/model.ply"):
        file_size = os.path.getsize(f"{workspace_dir}/output/model.ply") / (1024*1024)
        print(f"PLY file was created: {file_size:.1f} MB")
    else:
        print("PLY file was not created")
else:
    print("No model in sparse/0/ !")
# Out:
#  RECONSTRUCTION SUCCESSFUL!
#  Analyze 3D Model:
# Cameras: 1
# Images: 368
# Registered images: 368
# Points: 50183
# Observations: 487509
# Mean track length: 9.714624
# Mean observations per image: 1324.752717
# Mean reprojection error: 0.799155px
#  Convert to PLY...
# Final Model: /content/drive/MyDrive/3DCV/HW2/COLMAP/output/model.ply
# PLY file was created: 0.7 MB

# %%
# !pip install open3d
# Out:
# Collecting open3d
#   Downloading open3d-0.19.0-cp312-cp312-manylinux_2_31_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.12/dist-packages (from open3d) (2.0.2)
# Collecting dash>=2.6.0 (from open3d)
#   Downloading dash-3.2.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: werkzeug>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from open3d) (3.1.3)
# Requirement already satisfied: flask>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from open3d) (3.1.2)
# Requirement already satisfied: nbformat>=5.7.0 in /usr/local/lib/python3.12/dist-packages (from open3d) (5.10.4)
# Collecting configargparse (from open3d)
#   Downloading configargparse-1.7.1-py3-none-any.whl.metadata (24 kB)
# Collecting ipywidgets>=8.0.4 (from open3d)
#   Downloading ipywidgets-8.1.7-py3-none-any.whl.metadata (2.4 kB)
# Collecting addict (from open3d)
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: pillow>=9.3.0 in /usr/local/lib/python3.12/dist-packages (from open3d) (11.3.0)
# Requirement already satisfied: matplotlib>=3 in /usr/local/lib/python3.12/dist-packages (from open3d) (3.10.0)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.12/dist-packages (from open3d) (2.2.2)
# Requirement already satisfied: pyyaml>=5.4.1 in /usr/local/lib/python3.12/dist-packages (from open3d) (6.0.3)
# Requirement already satisfied: scikit-learn>=0.21 in /usr/local/lib/python3.12/dist-packages (from open3d) (1.6.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from open3d) (4.67.1)
# Collecting pyquaternion (from open3d)
#   Downloading pyquaternion-0.9.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from dash>=2.6.0->open3d) (5.24.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.12/dist-packages (from dash>=2.6.0->open3d) (8.7.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from dash>=2.6.0->open3d) (4.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from dash>=2.6.0->open3d) (2.32.4)
# Collecting retrying (from dash>=2.6.0->open3d)
#   Downloading retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from dash>=2.6.0->open3d) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from dash>=2.6.0->open3d) (75.2.0)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from flask>=3.0.0->open3d) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.12/dist-packages (from flask>=3.0.0->open3d) (8.3.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from flask>=3.0.0->open3d) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from flask>=3.0.0->open3d) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from flask>=3.0.0->open3d) (3.0.3)
# Collecting comm>=0.1.3 (from ipywidgets>=8.0.4->open3d)
#   Downloading comm-0.2.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=8.0.4->open3d) (7.34.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=8.0.4->open3d) (5.7.1)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets>=8.0.4->open3d)
#   Downloading widgetsnbextension-4.0.14-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=8.0.4->open3d) (3.0.15)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3->open3d) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3->open3d) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3->open3d) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3->open3d) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3->open3d) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3->open3d) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3->open3d) (2.9.0.post0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.7.0->open3d) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.7.0->open3d) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.7.0->open3d) (5.8.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0->open3d) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0->open3d) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.21->open3d) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.21->open3d) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.21->open3d) (3.6.0)
# Collecting jedi>=0.16 (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (4.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (0.27.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=5.7.0->open3d) (4.5.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=5.0.0->dash>=2.6.0->open3d) (8.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3->open3d) (1.17.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata->dash>=2.6.0->open3d) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->dash>=2.6.0->open3d) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->dash>=2.6.0->open3d) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->dash>=2.6.0->open3d) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->dash>=2.6.0->open3d) (2025.10.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.14)
# Downloading open3d-0.19.0-cp312-cp312-manylinux_2_31_x86_64.whl (447.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.7/447.7 MB 2.2 MB/s eta 0:00:00
# Downloading dash-3.2.0-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 108.2 MB/s eta 0:00:00
# Downloading ipywidgets-8.1.7-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 9.2 MB/s eta 0:00:00
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading configargparse-1.7.1-py3-none-any.whl (25 kB)
# Downloading pyquaternion-0.9.9-py3-none-any.whl (14 kB)
# Downloading comm-0.2.3-py3-none-any.whl (7.3 kB)
# Downloading widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 81.8 MB/s eta 0:00:00
# Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 68.7 MB/s eta 0:00:00
# Installing collected packages: addict, widgetsnbextension, retrying, pyquaternion, jedi, configargparse, comm, ipywidgets, dash, open3d
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.10
#     Uninstalling widgetsnbextension-3.6.10:
#       Successfully uninstalled widgetsnbextension-3.6.10
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# Successfully installed addict-2.4.0 comm-0.2.3 configargparse-1.7.1 dash-3.2.0 ipywidgets-8.1.7 jedi-0.19.2 open3d-0.19.0 pyquaternion-0.9.9 retrying-1.4.2 widgetsnbextension-4.0.14

# %%
# %pip install open3d
# !pip install open3d plotly

# %%
import open3d as o3d
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def visualize_point_cloud(ply_path):
    # Loding point cloud
    pcd = o3d.io.read_point_cloud(ply_path)

    print(f"Model Info:")
    print(f"   - # Points: {len(pcd.points):,}")
    print(f"   - Colors: {pcd.has_colors()}")
    print(f"   - Coordination Range:")

    points = np.asarray(pcd.points)
    if len(points) > 0:
        print(f"     X: {points[:,0].min():.2f} to {points[:,0].max():.2f}")
        print(f"     Y: {points[:,1].min():.2f} to {points[:,1].max():.2f}")
        print(f"     Z: {points[:,2].min():.2f} to {points[:,2].max():.2f}")

    # Interactive View
    print("Interactive View ...")
    o3d.visualization.draw_plotly([pcd])

    # Fixed View
    fig = plt.figure(figsize=(15, 5))

    #  (X-Z) View
    ax1 = fig.add_subplot(131)
    ax1.scatter(points[:,0], points[:,2], s=1, alpha=0.6)
    ax1.set_xlabel('X')
    ax1.set_ylabel('Z')
    ax1.set_title(' Top View (X-Z)')
    ax1.grid(True, alpha=0.3)
    ax1.axis('equal')

    # (X-Y) View
    ax2 = fig.add_subplot(132)
    ax2.scatter(points[:,0], points[:,1], s=1, alpha=0.6)
    ax2.set_xlabel('X')
    ax2.set_ylabel('Y')
    ax2.set_title('Front View (X-Y)')
    ax2.grid(True, alpha=0.3)
    ax2.axis('equal')

    # 3D View
    ax3 = fig.add_subplot(133, projection='3d')
    ax3.scatter(points[:,0], points[:,1], points[:,2], s=1, alpha=0.6)
    ax3.set_xlabel('X')
    ax3.set_ylabel('Y')
    ax3.set_zlabel('Z')
    ax3.set_title('3D View')

    plt.tight_layout()
    plt.show()

    return pcd

#  visualization
model_path = f"{workspace_dir}/output/model.ply"
point_cloud = visualize_point_cloud(model_path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2483007699.py in <cell line: 0>()
# ----> 1 import open3d as o3d
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#       4 from mpl_toolkits.mplot3d import Axes3D
#       5
#
# ModuleNotFoundError: No module named 'open3d'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
